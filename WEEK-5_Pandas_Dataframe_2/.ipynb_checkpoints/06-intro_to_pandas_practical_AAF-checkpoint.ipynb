# %% [markdown]
# A practical introduction to Pandas
# ===================

# %% [markdown]
# We have been asked to *analyze an otp dataset*, without much more information. This kind of scenario is more common than you might imagine!
#
# ## 1) Quickly examine the files in ~/Data/us_dot/otp. What do they contain, in both technical and functional terms? (Use any tool you want)

# %%
path_to_zips = '../data/us_dot/otp/'

# %%
! ls {path_to_zips}
# Out:
# On_Time_On_Time_Performance_2015_1.zip On_Time_On_Time_Performance_2015_5.zip
# On_Time_On_Time_Performance_2015_2.zip On_Time_On_Time_Performance_2015_6.zip
# On_Time_On_Time_Performance_2015_3.zip On_Time_On_Time_Performance_2015_7.zip
# On_Time_On_Time_Performance_2015_4.zip On_Time_On_Time_Performance_2015_8.zip

# %% [markdown]
# For this example, we are going to begin using the shell from within this notebook, with the ! notation:
#
# A ! sign before a line tells the notebook to send that line straight away to the underlying OS.
#
# \* Note that we can substitute python variables into the shell command. We do that by surrounding the name of the variable with curly braces ({}). That's what we are going to do with the `path_to_files` variable

# %% [markdown]
# ### Check what the files contain

# %%
! unzip -l {path_to_zips}On_Time_On_Time_Performance_2015_1.zip
# Out:
# Archive:  ../data/us_dot/otp/On_Time_On_Time_Performance_2015_1.zip
#   Length      Date    Time    Name
# ---------  ---------- -----   ----
# 211633432  04-16-2015 20:02   On_Time_On_Time_Performance_2015_1.csv
#     12054  04-16-2015 20:02   readme.html
# ---------                     -------
# 211645486                     2 files

# %% [markdown]
# Oh, it has a readme! Always good to read it.

# %% [markdown]
# ### Unzip the readme to the current directory
#
# Use the shell
#
# Remember, since the zip file contains several compressed files, we need to specify which one we want.

# %%
! unzip -o {path_to_zips}On_Time_On_Time_Performance_2015_1.zip readme.html -d $(pwd)
# Out:
# Archive:  ../data/us_dot/otp/On_Time_On_Time_Performance_2015_1.zip
#   inflating: /Users/aalmagro/Documents/KSchool_Jupyter/Jupyter_04/readme.html

# %% [raw]
# ! ls -lrt

# %% [markdown]
# ### Take a look at the beginning of the readme file
#
# using the shell

# %%
! head readme.html
# Out:
# <HTML>
# <HEAD>
# 	<TITLE> readme.html </TITLE>
# </HEAD>
# <BODY>
# 	<TABLE><TR><TD COLSPAN=2><H4>BACKGROUND</H4></TD></TR>
# 	<TR><TD COLSPAN=2>The data contained in the compressed file has been extracted from the
# 	On-Time Performance data table of the "On-Time" database from the TranStats data library.
# 	The time period is indicated in the name of the compressed file;
# 	for example, XXX_XXXXX_2001_1 contains data of the first month of the year 2001. </TD></TR>

# %% [markdown]
# The readme file is html. Luckily, we are working in an html environment.
#
# ### Display the contents of `readme.html` within the notebook
# (Hint: check out [IPython.display.IFrame](https://ipython.org/ipython-doc/3/api/generated/IPython.display.html))

# %%
from IPython.display import IFrame
IFrame('readme.html', width=700, height=350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="readme.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# That's some very good documentation!
#
# ### Summary:
#
# The files within the zip are " quoted csv's. They contain information on timeliness of departures in the US, at the departure level.

# %%
# have a look at the beginning of one of the files to see what they look like

! unzip -p {path_to_zips}On_Time_On_Time_Performance_2015_1.zip | head -n 2
# Out:
# "Year","Quarter","Month","DayofMonth","DayOfWeek","FlightDate","UniqueCarrier","AirlineID","Carrier","TailNum","FlightNum","OriginAirportID","OriginAirportSeqID","OriginCityMarketID","Origin","OriginCityName","OriginState","OriginStateFips","OriginStateName","OriginWac","DestAirportID","DestAirportSeqID","DestCityMarketID","Dest","DestCityName","DestState","DestStateFips","DestStateName","DestWac","CRSDepTime","DepTime","DepDelay","DepDelayMinutes","DepDel15","DepartureDelayGroups","DepTimeBlk","TaxiOut","WheelsOff","WheelsOn","TaxiIn","CRSArrTime","ArrTime","ArrDelay","ArrDelayMinutes","ArrDel15","ArrivalDelayGroups","ArrTimeBlk","Cancelled","CancellationCode","Diverted","CRSElapsedTime","ActualElapsedTime","AirTime","Flights","Distance","DistanceGroup","CarrierDelay","WeatherDelay","NASDelay","SecurityDelay","LateAircraftDelay","FirstDepTime","TotalAddGTime","LongestAddGTime","DivAirportLandings","DivReachedDest","DivActualElapsedTime","DivArrDelay","DivDistance","Div1Airport","Div1AirportID","Div1AirportSeqID","Div1WheelsOn","Div1TotalGTime","Div1LongestGTime","Div1WheelsOff","Div1TailNum","Div2Airport","Div2AirportID","Div2AirportSeqID","Div2WheelsOn","Div2TotalGTime","Div2LongestGTime","Div2WheelsOff","Div2TailNum","Div3Airport","Div3AirportID","Div3AirportSeqID","Div3WheelsOn","Div3TotalGTime","Div3LongestGTime","Div3WheelsOff","Div3TailNum","Div4Airport","Div4AirportID","Div4AirportSeqID","Div4WheelsOn","Div4TotalGTime","Div4LongestGTime","Div4WheelsOff","Div4TailNum","Div5Airport","Div5AirportID","Div5AirportSeqID","Div5WheelsOn","Div5TotalGTime","Div5LongestGTime","Div5WheelsOff","Div5TailNum",
# 2015,1,1,1,4,2015-01-01,"AA",19805,"AA","N787AA","1",12478,1247802,31703,"JFK","New York, NY","NY","36","New York",22,12892,1289203,32575,"LAX","Los Angeles, CA","CA","06","California",91,"0900","0855",-5.00,0.00,0.00,-1,"0900-0959",17.00,"0912","1230",7.00,"1230","1237",7.00,7.00,0.00,0,"1200-1259",0.00,"",0.00,390.00,402.00,378.00,1.00,2475.00,10,,,,,,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",

# %% [markdown]
# Pretty unreadable, so we go for a tool designed specifically for tabular data: **pandas**

# %% [markdown]
# ### Load some of the data (one of the files) into memory as a pandas dataframe. What functions do you need to use?
#
# Pro tip: there is no need to decompress the whole file. Check out zipfile.ZipFile

# %% [markdown]
# First, open a connection to one of the files

# %% [markdown]
# **Note:** *remember that all the files are indeed part files of the same .zip. And the Readme file is within the .zip.*

# %%
import os
import zipfile

filenames = os.listdir(path_to_zips)

zip_file = zipfile.ZipFile(path_to_zips + filenames[0])

# %%
print(filenames)
# Out:
# ['On_Time_On_Time_Performance_2015_1.zip', 'On_Time_On_Time_Performance_2015_2.zip', 'On_Time_On_Time_Performance_2015_3.zip', 'On_Time_On_Time_Performance_2015_4.zip', 'On_Time_On_Time_Performance_2015_5.zip', 'On_Time_On_Time_Performance_2015_6.zip', 'On_Time_On_Time_Performance_2015_7.zip', 'On_Time_On_Time_Performance_2015_8.zip']

# %% [markdown]
# zip_file is a connection to the compressed file, the .zip. We can use it to open a connection to one of the files it contains, which will behave like a normal uncompressed file that we had opened with open()

# %%
csv, readme = zip_file.filelist
print(csv)

csv_file = zip_file.open(csv.filename)
# Out:
# <ZipInfo filename='On_Time_On_Time_Performance_2015_1.csv' compress_type=deflate filemode='-rw-r--r--' file_size=211633432 compress_size=23058756>

# %% [markdown]
# Now we're ready to load the file into memory as a pandas dataframe. Remember to close the connections to the files!

# %%
# We reopen the file because we have already consumed the header line.
import pandas as pd

csv_file = zip_file.open(csv.filename)
df = pd.read_csv(csv_file)

csv_file.close()
zip_file.close()
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (77,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Let's start examining the data: show the beginning of the file. How many records does it contain?

# %%
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0  2015        1      1           1          4  2015-01-01            AA
# 1  2015        1      1           2          5  2015-01-02            AA
# 2  2015        1      1           3          6  2015-01-03            AA
# 3  2015        1      1           4          7  2015-01-04            AA
# 4  2015        1      1           5          1  2015-01-05            AA
#
#    AirlineID Carrier TailNum      ...       Div4TailNum  Div5Airport  \
# 0      19805      AA  N787AA      ...               NaN          NaN
# 1      19805      AA  N795AA      ...               NaN          NaN
# 2      19805      AA  N788AA      ...               NaN          NaN
# 3      19805      AA  N791AA      ...               NaN          NaN
# 4      19805      AA  N783AA      ...               NaN          NaN
#
#    Div5AirportID  Div5AirportSeqID Div5WheelsOn Div5TotalGTime  \
# 0            NaN               NaN          NaN            NaN
# 1            NaN               NaN          NaN            NaN
# 2            NaN               NaN          NaN            NaN
# 3            NaN               NaN          NaN            NaN
# 4            NaN               NaN          NaN            NaN
#
#   Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 0              NaN            NaN         NaN           NaN
# 1              NaN            NaN         NaN           NaN
# 2              NaN            NaN         NaN           NaN
# 3              NaN            NaN         NaN           NaN
# 4              NaN            NaN         NaN           NaN
#
# [5 rows x 110 columns]

# %%
df.shape
# Out:
# (469968, 110)

# %%
print(df.size)
df.size == df.shape[0] * df.shape[1]
# Out:
# 51696480
# True

# %%
df.dtypes
# Out:
# Year                    int64
# Quarter                 int64
# Month                   int64
# DayofMonth              int64
# DayOfWeek               int64
# FlightDate             object
# UniqueCarrier          object
# AirlineID               int64
# Carrier                object
# TailNum                object
# FlightNum               int64
# OriginAirportID         int64
# OriginAirportSeqID      int64
# OriginCityMarketID      int64
# Origin                 object
# OriginCityName         object
# OriginState            object
# OriginStateFips         int64
# OriginStateName        object
# OriginWac               int64
# DestAirportID           int64
# DestAirportSeqID        int64
# DestCityMarketID        int64
# Dest                   object
# DestCityName           object
# DestState              object
# DestStateFips           int64
# DestStateName          object
# DestWac                 int64
# CRSDepTime              int64
#                        ...
# Div2WheelsOn          float64
# Div2TotalGTime        float64
# Div2LongestGTime      float64
# Div2WheelsOff         float64
# Div2TailNum            object
# Div3Airport            object
# Div3AirportID         float64
# Div3AirportSeqID      float64
# Div3WheelsOn          float64
# Div3TotalGTime        float64
# Div3LongestGTime      float64
# Div3WheelsOff         float64
# Div3TailNum           float64
# Div4Airport           float64
# Div4AirportID         float64
# Div4AirportSeqID      float64
# Div4WheelsOn          float64
# Div4TotalGTime        float64
# Div4LongestGTime      float64
# Div4WheelsOff         float64
# Div4TailNum           float64
# Div5Airport           float64
# Div5AirportID         float64
# Div5AirportSeqID      float64
# Div5WheelsOn          float64
# Div5TotalGTime        float64
# Div5LongestGTime      float64
# Div5WheelsOff         float64
# Div5TailNum           float64
# Unnamed: 109          float64
# Length: 110, dtype: object

# %% [markdown]
# ## Trimming the data
#
# The table is quite wide, and it seems that there are many columns without much data. Which, exactly, are those? (let's consider empty a column that doesn't contain at least 1000 records, arbitrarily)

# %%
non_null_counts = df.count()

non_null_counts[non_null_counts < 1000]
# Out:
# DivReachedDest          973
# DivActualElapsedTime    684
# DivArrDelay             684
# DivDistance             971
# Div1WheelsOff           704
# Div1TailNum             704
# Div2Airport              27
# Div2AirportID            27
# Div2AirportSeqID         27
# Div2WheelsOn             27
# Div2TotalGTime           27
# Div2LongestGTime         27
# Div2WheelsOff             9
# Div2TailNum               9
# Div3Airport               2
# Div3AirportID             2
# Div3AirportSeqID          2
# Div3WheelsOn              2
# Div3TotalGTime            2
# Div3LongestGTime          2
# Div3WheelsOff             0
# Div3TailNum               0
# Div4Airport               0
# Div4AirportID             0
# Div4AirportSeqID          0
# Div4WheelsOn              0
# Div4TotalGTime            0
# Div4LongestGTime          0
# Div4WheelsOff             0
# Div4TailNum               0
# Div5Airport               0
# Div5AirportID             0
# Div5AirportSeqID          0
# Div5WheelsOn              0
# Div5TotalGTime            0
# Div5LongestGTime          0
# Div5WheelsOff             0
# Div5TailNum               0
# Unnamed: 109              0
# dtype: int64

# %% [markdown]
# It seems that the "diverted" fields, after the first, are often empty. No big surprise, since not that many flights must be diverted more than once in a month. Let's drop those columns, since we are not that interested in those, at least for now.

# %%
# Dropping inplace leads to confusion. Confusion leads to fear. 
# Fear leads to anger. Anger leads to hate. Hate leads to suffering.
df2 = df.drop(df.columns[non_null_counts < 1000], axis=1)

# %%
df2.shape
# Out:
# (469968, 71)

# %%
# Another way to do it

df.dropna(axis=1, thresh=1000).shape == df2.shape
# Out:
# True

# %% [markdown]
# Now that we have eliminated some inconvenient data columns, let's have a look at the rest: let's loook at how the location data is encoded.

# %% [markdown]
# #### Exercise:
#
# First, generate a list of the columns that have 'Origin' in their name
#
# Second, show a sample of the values that those columns take.
#
# Hint: we are going to use the str attribute of Series and Indexes

# %%
df[df.columns[df.columns.str.contains('Origin')]].sample(5)
# Out:
#         OriginAirportID  OriginAirportSeqID  OriginCityMarketID Origin  \
# 219549            13204             1320402               31454    MCO
# 150075            10821             1082103               30852    BWI
# 380887            11193             1119302               33105    CVG
# 370295            13487             1348702               31650    MSP
# 279419            13930             1393003               30977    ORD
#
#          OriginCityName OriginState  OriginStateFips OriginStateName  \
# 219549      Orlando, FL          FL               12         Florida
# 150075    Baltimore, MD          MD               24        Maryland
# 380887   Cincinnati, OH          KY               21        Kentucky
# 370295  Minneapolis, MN          MN               27       Minnesota
# 279419      Chicago, IL          IL               17        Illinois
#
#         OriginWac
# 219549         33
# 150075         35
# 380887         52
# 370295         63
# 279419         41

# %% [markdown]
# So much redundant information!

# %% [markdown]
# ## Fast forward
#
# Just taking out the redundant columns would take a while, so let's jump ahead with this list of interesting columns:

# %%
df2 = df[['FlightDate', 'DayOfWeek', 'Carrier', 'TailNum', 'FlightNum', 'Origin', 
         'OriginCityName', 'OriginStateName', 'Dest', 'DestCityName', 'DestStateName',
         'DepTime', 'DepDelay', 'AirTime', 'Distance']]
df.sample(5)
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 44085   2015        1      1          10          6  2015-01-10            AS
# 393350  2015        1      1          27          2  2015-01-27            EV
# 160927  2015        1      1          10          6  2015-01-10            WN
# 462556  2015        1      1           7          3  2015-01-07            EV
# 212991  2015        1      1          27          2  2015-01-27            WN
#
#         AirlineID Carrier TailNum      ...       Div4TailNum  Div5Airport  \
# 44085       19930      AS  N464AS      ...               NaN          NaN
# 393350      20366      EV  N31131      ...               NaN          NaN
# 160927      19393      WN  N7742B      ...               NaN          NaN
# 462556      20366      EV  N11548      ...               NaN          NaN
# 212991      19393      WN  N8611F      ...               NaN          NaN
#
#         Div5AirportID  Div5AirportSeqID Div5WheelsOn Div5TotalGTime  \
# 44085             NaN               NaN          NaN            NaN
# 393350            NaN               NaN          NaN            NaN
# 160927            NaN               NaN          NaN            NaN
# 462556            NaN               NaN          NaN            NaN
# 212991            NaN               NaN          NaN            NaN
#
#        Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 44085               NaN            NaN         NaN           NaN
# 393350              NaN            NaN         NaN           NaN
# 160927              NaN            NaN         NaN           NaN
# 462556              NaN            NaN         NaN           NaN
# 212991              NaN            NaN         NaN           NaN
#
# [5 rows x 110 columns]

# %% [markdown]
# ## Formatting columns and parsing dates and times
#
# Hurray! we have almost cleaned our dataset. Soon we will begin to do some actual work with it.

# %%
df2.dtypes
# Out:
# FlightDate          object
# DayOfWeek            int64
# Carrier             object
# TailNum             object
# FlightNum            int64
# Origin              object
# OriginCityName      object
# OriginStateName     object
# Dest                object
# DestCityName        object
# DestStateName       object
# DepTime            float64
# DepDelay           float64
# AirTime            float64
# Distance           float64
# dtype: object

# %% [markdown]
# Pandas interpreted the Deptime column as ints and the FlighDate column as strings. We want to combine them and parse them into a DateTime column, so that we can use them properly as datetimes.

# %% [markdown]
# First step:
#
# #### Exercise
#
# Define a function that will parse our int hours into a reasonable format ("HH:MM"). It should take only one int hour and return the appropriate representation.

# %%
# We'll need to take an int and return a string of the appropriate format
import numpy as np
def deptime_to_string(num):
    if num!=num:#If np.nan better handle this
        num =0.0;

    hour = int(num / 100) % 24 # There are 24s in the data, which datetime doesn't like
    minute = int(num % 100)
    

    return '%02d:%02d' % (hour, minute)

deptime_to_string(2423.0)
#deptime_to_string(np.nan)
# Out:
# '00:23'

# %% [markdown]
# Now, we can use that function to build datetime strings that we will then pass to pd.to_datetime, with a format we will specify. Let's do that
#
# Hint: Check out [pd.to_datetime's documentatoin](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html) for info on the acceptable format.

# %% [markdown]
# #### Exercise
#
# Overwrite the 'DepTime' column with its version in the proper format
#
# Hint: Before overwriting your column in the dataframe, make sure that everything works by assigning the modified column to a Series variable (this takes care of not messing up with the index!).

# %%
#series = df2['DepTime'].apply(deptime_to_string)
series = df2['DepTime'].dropna().apply(deptime_to_string)
series.head()
# Out:
# 0    08:55
# 1    08:50
# 2    08:53
# 3    08:53
# 4    08:53
# Name: DepTime, dtype: object

# %%
df2['DepTimeStr'] = series
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# What happened to the nas? They are still nas, because our 
# Series didn't contain them. Therefore, when we put the 
# Series back into the Dataframe, those cells stayed empty.
df2['DepTimeStr'].count()
# Out:
# 458311

# %% [markdown]
# #### Exercise
#
# Now, create a DepDateTime with the proper type using `pd.to_datetime`

# %%
# This is the format pd.to_datetime needs:

ts = pd.to_datetime('2015-01-15 08:30')
ts
# Out:
# Timestamp('2015-01-15 08:30:00')

# %%
departure_datetimes = pd.to_datetime(df2['FlightDate'] + ' ' + df2['DepTimeStr'])
df2['DepDateTime'] = departure_datetimes

# Drop the now-redundant columns
df2 = df2.drop(['FlightDate', 'DepTime', 'DepTimeStr'], axis=1)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df2.sample(5)
# Out:
#         DayOfWeek Carrier TailNum  FlightNum Origin     OriginCityName  \
# 126605          1      VX  N635VA         90    SFO  San Francisco, CA
# 73221           4      DL  N324NB        860    SNA      Santa Ana, CA
# 207743          7      WN  N428WN       1958    LGA       New York, NY
# 61336           3      B6  N267JB        518    JFK       New York, NY
# 179271          4      WN  N8602F        793    MCI    Kansas City, MO
#
#        OriginStateName Dest     DestCityName  DestStateName  DepDelay  \
# 126605      California  IAD   Washington, DC       Virginia      -9.0
# 73221       California  MSP  Minneapolis, MN      Minnesota      -3.0
# 207743        New York  MDW      Chicago, IL       Illinois      40.0
# 61336         New York  BOS       Boston, MA  Massachusetts       NaN
# 179271        Missouri  MDW      Chicago, IL       Illinois      -2.0
#
#         AirTime  Distance         DepDateTime
# 126605    287.0    2419.0 2015-01-26 13:56:00
# 73221     188.0    1522.0 2015-01-01 06:42:00
# 207743    113.0     725.0 2015-01-25 16:35:00
# 61336       NaN     187.0                 NaT
# 179271     62.0     405.0 2015-01-15 15:53:00

# %% [markdown]
# ### Inspect the types, see if everything is in order

# %%
df2.dtypes
# Out:
# DayOfWeek                   int64
# Carrier                    object
# TailNum                    object
# FlightNum                   int64
# Origin                     object
# OriginCityName             object
# OriginStateName            object
# Dest                       object
# DestCityName               object
# DestStateName              object
# DepDelay                  float64
# AirTime                   float64
# Distance                  float64
# DepDateTime        datetime64[ns]
# dtype: object

# %% [markdown]
# ## Examining the data

# %% [markdown]
# Finally clean! Let's start to do some preliminary work on the data.

# %% [markdown]
# #### Exercise:
#
# Find the biggest delays.
#
# How would you find the 5 maximum delays?

# %%
df2.sort_values(by='DepDelay', ascending=False).head()
# Out:
#         DayOfWeek Carrier TailNum  FlightNum Origin    OriginCityName  \
# 21523           5      AA  N598AA       1322    BHM    Birmingham, AL
# 11524           7      AA  N5DGAA        224    LAS     Las Vegas, NV
# 18198           2      AA  N586AA       1242    FAT        Fresno, CA
# 108152          3      AA  N4XNAA       2385    JAX  Jacksonville, FL
# 26001           7      AA  N469AA       1595    AUS        Austin, TX
#
#        OriginStateName Dest           DestCityName DestStateName  DepDelay  \
# 21523          Alabama  DFW  Dallas/Fort Worth, TX         Texas    1988.0
# 11524           Nevada  LAX        Los Angeles, CA    California    1604.0
# 18198       California  DFW  Dallas/Fort Worth, TX         Texas    1551.0
# 108152         Florida  DFW  Dallas/Fort Worth, TX         Texas    1457.0
# 26001            Texas  DFW  Dallas/Fort Worth, TX         Texas    1450.0
#
#         AirTime  Distance         DepDateTime
# 21523      99.0     597.0 2015-01-23 16:08:00
# 11524      42.0     236.0 2015-01-18 14:14:00
# 18198     155.0    1313.0 2015-01-27 08:50:00
# 108152    144.0     918.0 2015-01-21 12:40:00
# 26001      37.0     190.0 2015-01-11 07:00:00

# %% [markdown]
# #### Exercise
#
# What was the average delay for this month? Standard deviation and typical value?

# %%
df2['DepDelay'].describe()
# Out:
# count    458311.000000
# mean          9.759471
# std          36.636491
# min         -48.000000
# 25%          -5.000000
# 50%          -2.000000
# 75%           9.000000
# max        1988.000000
# Name: DepDelay, dtype: float64

# %% [markdown]
# Also: a quick look at the correlation between the numerical variables is extremely easy with pandas:

# %%
df2.corr()
# Out:
#            DayOfWeek  FlightNum  DepDelay   AirTime  Distance
# DayOfWeek   1.000000   0.016484  0.017254  0.027161  0.021530
# FlightNum   0.016484   1.000000  0.024760 -0.335150 -0.349912
# DepDelay    0.017254   0.024760  1.000000  0.013282  0.013871
# AirTime     0.027161  -0.335150  0.013282  1.000000  0.981376
# Distance    0.021530  -0.349912  0.013871  0.981376  1.000000

# %% [markdown]
# #### Exercise
#
# What is the origin that has the highest average delay? We'll first group by tail number (the *license plate* of a plane) and then calculate the relevant statistic for each group (group of *departures*)

# %%
#grouped_by_plane = df2.groupby('TailNum')
grouped_by_plane = df2.groupby('Origin')
type(grouped_by_plane)
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %%
grouped_by_plane['DepDelay'].mean().sort_values(ascending=False).head(10)
# Out:
# Origin
# DVL    35.627907
# JMS    34.322581
# IMT    32.381818
# OTH    30.375000
# CEC    28.881356
# TTN    26.942982
# SCE    26.492063
# ILG    26.461538
# APN    25.653061
# ACV    25.088435
# Name: DepDelay, dtype: float64

# %% [markdown]
# But the mean can be only meaningful if we had enough samples. Lets check that! We can aggregate *mean* and *count* at the same time.

# %%
#delays_by_plane = grouped_by_plane['DepDelay'].agg(['mean', 'count'])
delays_by_origin = grouped_by_plane['DepDelay'].agg(['mean', 'count'])

# %%
#delays_by_plane.sort_values('mean', ascending=False)
delays_by_origin.sort_values('mean', ascending=False)
# Out:
#              mean  count
# Origin
# DVL     35.627907     43
# JMS     34.322581     62
# IMT     32.381818     55
# OTH     30.375000     16
# CEC     28.881356     59
# TTN     26.942982    228
# SCE     26.492063     63
# ILG     26.461538     26
# APN     25.653061     49
# ACV     25.088435    147
# BPT     24.595506     89
# ABR     24.500000     60
# PIH     23.633333     60
# EAU     22.836066     61
# GUC     22.095890     73
# ESC     21.666667     48
# ASE     20.867797    590
# TVC     20.690217    184
# ROW     20.654321     81
# ORD     19.962051  22425
# JAC     18.787172    343
# STC     18.509091     55
# SBN     18.491892    370
# BIS     18.302632    304
# FAT     18.125547    685
# COS     17.912969    586
# EGE     17.760274    292
# ALO     17.122449     49
# BMI     16.418103    232
# CID     16.200942    637
# ...           ...    ...
# LIH      1.990576    955
# SIT      1.793478     92
# GPT      1.621622    333
# EYW      1.584362    243
# EWN      1.400000     55
# BIL      1.128440    218
# PPG      1.100000     10
# BLI      1.032258     93
# ANC      1.005111   1174
# FAI      0.896104    154
# HRL      0.888889    279
# LRD      0.465347    202
# DAB      0.458333    120
# OME      0.103448     58
# HOB      0.069767     43
# CLD     -0.405000    200
# HLN     -0.682243    107
# BRD     -1.576923     52
# CDC     -2.056604     53
# PSE     -2.069444     72
# BET     -2.312500     80
# TWF     -5.517857     56
# LWS     -6.358491     53
# ADK     -6.666667      9
# BTM     -7.152542     59
# YAK     -8.016949     59
# CDV     -8.333333     60
# ADQ     -8.827586     29
# EKO     -8.852459     61
# CNY     -8.888889     54
#
# [312 rows x 2 columns]

# %% [markdown]
# Awesome! now, let's look at the average delay of the planes with some departures (let's say, at least 15)

# %%
consistently_delayed = delays_by_origin[delays_by_origin['count'] > 14]
highly_delayed = consistently_delayed.sort_values('mean', ascending=False).head(100)

# What companies run the rank 5/10 most delayed?
df2.join(highly_delayed.head(5), on='Origin', how='inner')['Carrier'].unique()
# Out:
# array(['OO'], dtype=object)

# %% [markdown]
# #### Exercise:
#
# Show cities by descending number of airports

# %%
airports_by_city = df2.groupby('OriginCityName')['Origin'].unique()
#We have a list of Airport code for each city now.
airports_by_city.map(lambda x: len(x)).sort_values(ascending=False).head()
# Out:
# OriginCityName
# Houston, TX         2
# Chicago, IL         2
# New York, NY        2
# Washington, DC      2
# Fayetteville, NC    1
# Name: Origin, dtype: int64

# %% [raw]
# print(df2.groupby('OriginCityName')['Origin'].unique())

# %% [markdown]
# ## Plotting
#
# There are several ways in which we could go about plotting this dataset in order to get acquainted with it.

# %% [markdown]
# For example, do the delays have a relationship with the number of departures a plane does?

# %% [markdown]
# #### Exercise
#
# Do a scatter plot with matplotlib. Check the documentation

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

ax = delays_by_origin.plot.scatter('mean', 'count', alpha=.2)
#ax.set_xlim(-20,240)
#ax.set_ylim(-10,240)

# %% [markdown]
# #### Exercise:
#
# Plot the distribution of delays as a histogram, both with a linear and a logarithmic scale

# %%
# Little trick: Just by importing seaborn, it will change 
# matplotlib defaults and make your graphs much prettier.!!

import seaborn as sns

ax = df['DepDelay'].hist(bins=500)
ax.set_xlim(-100, 500)

plt.title('Number of flights per delay bin')
# Out:
# Text(0.5,1,'Number of flights per delay bin')

# %%
# We can make any axis logarithmic in order to see better a very unequal distribution

ax = df['DepDelay'].hist(bins=500)
ax.set_xlim(-100, 500)
plt.title('Num flights per delay bin')

plt.yscale('log')

# %% [markdown]
# ### Another question:
#
# how do the delays stack over the course of the day? We are going to look at it by plotting the distribution of delays for each hour of the day. The very best way to compare distributions side by side is a boxplot, so we'll use that.

# %%
help(plt.boxplot)
# Out:
# Help on function boxplot in module matplotlib.pyplot:
#
# boxplot(x, notch=None, sym=None, vert=None, whis=None, positions=None, widths=None, patch_artist=None, bootstrap=None, usermedians=None, conf_intervals=None, meanline=None, showmeans=None, showcaps=None, showbox=None, showfliers=None, boxprops=None, labels=None, flierprops=None, medianprops=None, meanprops=None, capprops=None, whiskerprops=None, manage_xticks=True, autorange=False, zorder=None, hold=None, data=None)
#     Make a box and whisker plot.
#
#     Make a box and whisker plot for each column of ``x`` or each
#     vector in sequence ``x``.  The box extends from the lower to
#     upper quartile values of the data, with a line at the median.
#     The whiskers extend from the box to show the range of the
#     data.  Flier points are those past the end of the whiskers.
#
#     Parameters
#     ----------
#     x : Array or a sequence of vectors.
#         The input data.
#
#     notch : bool, optional (False)
#         If `True`, will produce a notched box plot. Otherwise, a
#         rectangular boxplot is produced. The notches represent the
#         confidence interval (CI) around the median. See the entry
#         for the ``bootstrap`` parameter for information regarding
#         how the locations of the notches are computed.
#
#         .. note::
#
#             In cases where the values of the CI are less than the
#             lower quartile or greater than the upper quartile, the
#             notches will extend beyond the box, giving it a
#             distinctive "flipped" appearance. This is expected
#             behavior and consistent with other statistical
#             visualization packages.
#
#     sym : str, optional
#         The default symbol for flier points. Enter an empty string
#         ('') if you don't want to show fliers. If `None`, then the
#         fliers default to 'b+'  If you want more control use the
#         flierprops kwarg.
#
#     vert : bool, optional (True)
#         If `True` (default), makes the boxes vertical. If `False`,
#         everything is drawn horizontally.
#
#     whis : float, sequence, or string (default = 1.5)
#         As a float, determines the reach of the whiskers to the beyond the
#         first and third quartiles. In other words, where IQR is the
#         interquartile range (`Q3-Q1`), the upper whisker will extend to
#         last datum less than `Q3 + whis*IQR`). Similarly, the lower whisker
#         will extend to the first datum greater than `Q1 - whis*IQR`.
#         Beyond the whiskers, data
#         are considered outliers and are plotted as individual
#         points. Set this to an unreasonably high value to force the
#         whiskers to show the min and max values. Alternatively, set
#         this to an ascending sequence of percentile (e.g., [5, 95])
#         to set the whiskers at specific percentiles of the data.
#         Finally, ``whis`` can be the string ``'range'`` to force the
#         whiskers to the min and max of the data.
#
#     bootstrap : int, optional
#         Specifies whether to bootstrap the confidence intervals
#         around the median for notched boxplots. If ``bootstrap`` is
#         None, no bootstrapping is performed, and notches are
#         calculated using a Gaussian-based asymptotic approximation
#         (see McGill, R., Tukey, J.W., and Larsen, W.A., 1978, and
#         Kendall and Stuart, 1967). Otherwise, bootstrap specifies
#         the number of times to bootstrap the median to determine its
#         95% confidence intervals. Values between 1000 and 10000 are
#         recommended.
#
#     usermedians : array-like, optional
#         An array or sequence whose first dimension (or length) is
#         compatible with ``x``. This overrides the medians computed
#         by matplotlib for each element of ``usermedians`` that is not
#         `None`. When an element of ``usermedians`` is None, the median
#         will be computed by matplotlib as normal.
#
#     conf_intervals : array-like, optional
#         Array or sequence whose first dimension (or length) is
#         compatible with ``x`` and whose second dimension is 2. When
#         the an element of ``conf_intervals`` is not None, the
#         notch locations computed by matplotlib are overridden
#         (provided ``notch`` is `True`). When an element of
#         ``conf_intervals`` is `None`, the notches are computed by the
#         method specified by the other kwargs (e.g., ``bootstrap``).
#
#     positions : array-like, optional
#         Sets the positions of the boxes. The ticks and limits are
#         automatically set to match the positions. Defaults to
#         `range(1, N+1)` where N is the number of boxes to be drawn.
#
#     widths : scalar or array-like
#         Sets the width of each box either with a scalar or a
#         sequence. The default is 0.5, or ``0.15*(distance between
#         extreme positions)``, if that is smaller.
#
#     patch_artist : bool, optional (False)
#         If `False` produces boxes with the Line2D artist. Otherwise,
#         boxes and drawn with Patch artists.
#
#     labels : sequence, optional
#         Labels for each dataset. Length must be compatible with
#         dimensions  of ``x``.
#
#     manage_xticks : bool, optional (True)
#         If the function should adjust the xlim and xtick locations.
#
#     autorange : bool, optional (False)
#         When `True` and the data are distributed such that the  25th and
#         75th percentiles are equal, ``whis`` is set to ``'range'`` such
#         that the whisker ends are at the minimum and maximum of the
#         data.
#
#     meanline : bool, optional (False)
#         If `True` (and ``showmeans`` is `True`), will try to render
#         the mean as a line spanning the full width of the box
#         according to ``meanprops`` (see below). Not recommended if
#         ``shownotches`` is also True. Otherwise, means will be shown
#         as points.
#
#     zorder : scalar, optional (None)
#         Sets the zorder of the boxplot.
#
#     Other Parameters
#     ----------------
#     showcaps : bool, optional (True)
#         Show the caps on the ends of whiskers.
#     showbox : bool, optional (True)
#         Show the central box.
#     showfliers : bool, optional (True)
#         Show the outliers beyond the caps.
#     showmeans : bool, optional (False)
#         Show the arithmetic means.
#     capprops : dict, optional (None)
#         Specifies the style of the caps.
#     boxprops : dict, optional (None)
#         Specifies the style of the box.
#     whiskerprops : dict, optional (None)
#         Specifies the style of the whiskers.
#     flierprops : dict, optional (None)
#         Specifies the style of the fliers.
#     medianprops : dict, optional (None)
#         Specifies the style of the median.
#     meanprops : dict, optional (None)
#         Specifies the style of the mean.
#
#     Returns
#     -------
#     result : dict
#       A dictionary mapping each component of the boxplot to a list
#       of the :class:`matplotlib.lines.Line2D` instances
#       created. That dictionary has the following keys (assuming
#       vertical boxplots):
#
#       - ``boxes``: the main body of the boxplot showing the
#         quartiles and the median's confidence intervals if
#         enabled.
#
#       - ``medians``: horizontal lines at the median of each box.
#
#       - ``whiskers``: the vertical lines extending to the most
#         extreme, non-outlier data points.
#
#       - ``caps``: the horizontal lines at the ends of the
#         whiskers.
#
#       - ``fliers``: points representing data that extend beyond
#         the whiskers (fliers).
#
#       - ``means``: points or lines representing the means.
#
#     Examples
#     --------
#     .. plot:: mpl_examples/statistics/boxplot_demo.py
#
#     .. note::
#         In addition to the above described arguments, this function can take a
#         **data** keyword argument. If such a **data** argument is given, the
#         following arguments are replaced by **data[<arg>]**:
#
#         * All positional and all keyword arguments.

# %% [markdown]
# We need to provide `plt.boxplot()` with a sequence that contains 24 elements. Each of those will be a sequence containing every individual delay for one hour of the day. We'll need, therefore, to extract hours of the day for each departure and group based on that.

# %%
# Now, we can iterate over the groups and extract the delays. 
# We keep them in two different vectors because that is what boxplot wants

df2['DepHour'] =  df2['DepDateTime'].map(lambda x: x.hour)

by_hour = df2.groupby('DepHour')

hours = []
groups = []

for h, g in by_hour:
    hours.append("%02d" % h)
    groups.append(g['DepDelay'])

# %%
# We have create a groupby object. That object behaves like a list.
# Each element of that list is a (key, dataframe) tuple.
# You can think of the key as the group's name. The dataframe
# contains all the rows in the original dataframe that correspond 
# to that key: Here, group '0.0' contains all rows from flights 
# that departed on hour 0.

print(type(by_hour))
print(list(by_hour))
print(list(by_hour)[0], list(by_hour)[0][1].shape)
# Out:
# <class 'pandas.core.groupby.DataFrameGroupBy'>
# [(0.0,         DayOfWeek Carrier TailNum  FlightNum Origin     OriginCityName  \
# 2290            1      AA  N3EEAA         91    ORD        Chicago, IL
# 4323            4      AA  N3EXAA        234    MIA          Miami, FL
# 4922            3      AA  N3HRAA        219    LAX    Los Angeles, CA
# 4923            4      AA  N3HUAA        219    LAX    Los Angeles, CA
# 4924            5      AA  N3GWAA        219    LAX    Los Angeles, CA
# 4931            5      AA  N3AJAA        219    LAX    Los Angeles, CA
# 4937            4      AA  N3LEAA        219    LAX    Los Angeles, CA
# 4940            7      AA  N3CDAA        219    LAX    Los Angeles, CA
# 4943            3      AA  N3HAAA        219    LAX    Los Angeles, CA
# 5639            1      AA  N3EPAA        272    SFO  San Francisco, CA
# 5645            7      AA  N3BJAA        272    SFO  San Francisco, CA
# 5650            5      AA  N3EFAA        272    SFO  San Francisco, CA
# 5651            6      AA  N3FAAA        272    SFO  San Francisco, CA
# 5652            7      AA  N3FRAA        272    SFO  San Francisco, CA
# 5655            3      AA  N3JEAA        272    SFO  San Francisco, CA
# 5656            4      AA  N3GWAA        272    SFO  San Francisco, CA
# 5659            7      AA  N3LKAA        272    SFO  San Francisco, CA
# 5664            5      AA  N3JGAA        272    SFO  San Francisco, CA
# 5968            1      AA  N5ESAA        285    LAX    Los Angeles, CA
# 5980            3      AA  N5DGAA        286    LIH          Lihue, HI
# 8505            3      AA  N3BHAA        260    LAX    Los Angeles, CA
# 8506            4      AA  N3AKAA        260    LAX    Los Angeles, CA
# 8507            5      AA  N3FHAA        260    LAX    Los Angeles, CA
# 8508            6      AA  N3DHAA        260    LAX    Los Angeles, CA
# 8509            7      AA  N3JMAA        260    LAX    Los Angeles, CA
# 8510            1      AA  N3BHAA        260    LAX    Los Angeles, CA
# 8511            2      AA  N3HGAA        260    LAX    Los Angeles, CA
# 8512            3      AA  N3DUAA        260    LAX    Los Angeles, CA
# 8513            4      AA  N3BAAA        260    LAX    Los Angeles, CA
# 8514            5      AA  N3FFAA        260    LAX    Los Angeles, CA
# ...           ...     ...     ...        ...    ...                ...
# 516343          2      F9  N208FR       1126    LAS      Las Vegas, NV
# 516482          3      F9  N953FR        736    DEN         Denver, CO
# 516512          4      F9  N205FR       1114    LAS      Las Vegas, NV
# 516537          4      F9  N213FR        223    ATL        Atlanta, GA
# 516547          4      F9  N216FR        507    LGA       New York, NY
# 516561          4      F9  N227FR       1126    LAS      Las Vegas, NV
# 516640          4      F9  N922FR       1478    LAX    Los Angeles, CA
# 516708          4      F9  N939FR        736    DEN         Denver, CO
# 516720          4      F9  N943FR       1136    LAS      Las Vegas, NV
# 516750          4      F9  N953FR        682    DEN         Denver, CO
# 516769          5      F9  N203FR       1126    LAS      Las Vegas, NV
# 516804          5      F9  N213FR        619    MIA          Miami, FL
# 516830          5      F9  N223FR        507    LGA       New York, NY
# 516888          5      F9  N919FR       1457    ATL        Atlanta, GA
# 516892          5      F9  N921FR        736    DEN         Denver, CO
# 516926          5      F9  N926FR       1120    LAS      Las Vegas, NV
# 516939          5      F9  N929FR        602    DEN         Denver, CO
# 516958          5      F9  N933FR        682    DEN         Denver, CO
# 517041          6      F9  N205FR       1114    LAS      Las Vegas, NV
# 517053          6      F9  N207FR        507    LGA       New York, NY
# 517055          6      F9  N209FR       1126    LAS      Las Vegas, NV
# 517194          6      F9  N928FR        682    DEN         Denver, CO
# 517211          6      F9  N933FR        565    DEN         Denver, CO
# 517230          6      F9  N939FR        620    DEN         Denver, CO
# 517235          6      F9  N943FR        300    DEN         Denver, CO
# 517334          7      F9  N216FR        565    DEN         Denver, CO
# 517365          3      F9  N912FR       1456    LAS      Las Vegas, NV
# 517372          3      F9  N919FR        602    DEN         Denver, CO
# 517415          3      F9  N926FR       1136    LAS      Las Vegas, NV
# 517530          4      F9  N208FR        507    LGA       New York, NY
#
#        OriginStateName Dest           DestCityName   DestStateName  DepDelay  \
# 2290          Illinois  DFW  Dallas/Fort Worth, TX           Texas     105.0
# 4323           Florida  BWI          Baltimore, MD        Maryland     196.0
# 4922        California  ORD            Chicago, IL        Illinois      15.0
# 4923        California  ORD            Chicago, IL        Illinois      17.0
# 4924        California  ORD            Chicago, IL        Illinois      36.0
# 4931        California  ORD            Chicago, IL        Illinois       5.0
# 4937        California  ORD            Chicago, IL        Illinois       7.0
# 4940        California  ORD            Chicago, IL        Illinois      34.0
# 4943        California  ORD            Chicago, IL        Illinois      10.0
# 5639        California  MIA              Miami, FL         Florida      25.0
# 5645        California  MIA              Miami, FL         Florida      12.0
# 5650        California  MIA              Miami, FL         Florida      10.0
# 5651        California  MIA              Miami, FL         Florida      16.0
# 5652        California  MIA              Miami, FL         Florida      14.0
# 5655        California  MIA              Miami, FL         Florida      27.0
# 5656        California  MIA              Miami, FL         Florida      15.0
# 5659        California  MIA              Miami, FL         Florida       3.0
# 5664        California  MIA              Miami, FL         Florida      14.0
# 5968        California  LIH              Lihue, HI          Hawaii     410.0
# 5980            Hawaii  LAX        Los Angeles, CA      California     161.0
# 8505        California  MIA              Miami, FL         Florida      -5.0
# 8506        California  MIA              Miami, FL         Florida      -5.0
# 8507        California  MIA              Miami, FL         Florida      -6.0
# 8508        California  MIA              Miami, FL         Florida      -3.0
# 8509        California  MIA              Miami, FL         Florida      -3.0
# 8510        California  MIA              Miami, FL         Florida      -4.0
# 8511        California  MIA              Miami, FL         Florida      -5.0
# 8512        California  MIA              Miami, FL         Florida      -2.0
# 8513        California  MIA              Miami, FL         Florida      -4.0
# 8514        California  MIA              Miami, FL         Florida     -10.0
# ...                ...  ...                    ...             ...       ...
# 516343          Nevada  IAD         Washington, DC        Virginia      -1.0
# 516482        Colorado  CVG         Cincinnati, OH        Kentucky      38.0
# 516512          Nevada  CLE          Cleveland, OH            Ohio      47.0
# 516537         Georgia  AUS             Austin, TX           Texas     525.0
# 516547        New York  DEN             Denver, CO        Colorado      89.0
# 516561          Nevada  IAD         Washington, DC        Virginia       1.0
# 516640      California  ATL            Atlanta, GA         Georgia      64.0
# 516708        Colorado  CVG         Cincinnati, OH        Kentucky       7.0
# 516720          Nevada  AUS             Austin, TX           Texas      12.0
# 516750        Colorado  MCO            Orlando, FL         Florida       3.0
# 516769          Nevada  IAD         Washington, DC        Virginia       3.0
# 516804         Florida  DEN             Denver, CO        Colorado     196.0
# 516830        New York  DEN             Denver, CO        Colorado      73.0
# 516888         Georgia  LAS          Las Vegas, NV          Nevada     225.0
# 516892        Colorado  CVG         Cincinnati, OH        Kentucky      -1.0
# 516926          Nevada  CVG         Cincinnati, OH        Kentucky     102.0
# 516939        Colorado  IND       Indianapolis, IN         Indiana       0.0
# 516958        Colorado  MCO            Orlando, FL         Florida       7.0
# 517041          Nevada  CLE          Cleveland, OH            Ohio      85.0
# 517053        New York  DEN             Denver, CO        Colorado      82.0
# 517055          Nevada  IAD         Washington, DC        Virginia      -7.0
# 517194        Colorado  MCO            Orlando, FL         Florida       8.0
# 517211        Colorado  RDU     Raleigh/Durham, NC  North Carolina      15.0
# 517230        Colorado  DTW            Detroit, MI        Michigan      21.0
# 517235        Colorado  TPA              Tampa, FL         Florida       9.0
# 517334        Colorado  RDU     Raleigh/Durham, NC  North Carolina      21.0
# 517365          Nevada  ATL            Atlanta, GA         Georgia     123.0
# 517372        Colorado  IND       Indianapolis, IN         Indiana      -7.0
# 517415          Nevada  AUS             Austin, TX           Texas      13.0
# 517530        New York  DEN             Denver, CO        Colorado     117.0
#
#         AirTime  Distance         DepDateTime  DepHour
# 2290      110.0     802.0 2015-07-06 00:00:00      0.0
# 4323      129.0     946.0 2015-07-16 00:36:00      0.0
# 4922      213.0    1744.0 2015-07-08 00:10:00      0.0
# 4923      206.0    1744.0 2015-07-09 00:12:00      0.0
# 4924      202.0    1744.0 2015-07-10 00:31:00      0.0
# 4931      197.0    1744.0 2015-07-17 00:00:00      0.0
# 4937      217.0    1744.0 2015-07-23 00:02:00      0.0
# 4940      209.0    1744.0 2015-07-26 00:29:00      0.0
# 4943      207.0    1744.0 2015-07-29 00:05:00      0.0
# 5639      315.0    2585.0 2015-07-06 00:24:00      0.0
# 5645      309.0    2585.0 2015-07-12 00:11:00      0.0
# 5650      305.0    2585.0 2015-07-17 00:09:00      0.0
# 5651      303.0    2585.0 2015-07-18 00:15:00      0.0
# 5652      308.0    2585.0 2015-07-19 00:13:00      0.0
# 5655      300.0    2585.0 2015-07-22 00:26:00      0.0
# 5656      299.0    2585.0 2015-07-23 00:14:00      0.0
# 5659      313.0    2585.0 2015-07-26 00:02:00      0.0
# 5664      302.0    2585.0 2015-07-31 00:13:00      0.0
# 5968      330.0    2615.0 2015-07-27 00:20:00      0.0
# 5980      296.0    2615.0 2015-07-08 00:42:00      0.0
# 8505      292.0    2342.0 2015-07-01 00:05:00      0.0
# 8506      288.0    2342.0 2015-07-02 00:05:00      0.0
# 8507      285.0    2342.0 2015-07-03 00:04:00      0.0
# 8508      285.0    2342.0 2015-07-04 00:07:00      0.0
# 8509      277.0    2342.0 2015-07-05 00:07:00      0.0
# 8510      284.0    2342.0 2015-07-06 00:06:00      0.0
# 8511      287.0    2342.0 2015-07-07 00:05:00      0.0
# 8512      276.0    2342.0 2015-07-08 00:08:00      0.0
# 8513      273.0    2342.0 2015-07-09 00:06:00      0.0
# 8514      295.0    2342.0 2015-07-10 00:00:00      0.0
# ...         ...       ...                 ...      ...
# 516343    249.0    2065.0 2015-07-07 00:14:00      0.0
# 516482    122.0    1069.0 2015-07-22 00:43:00      0.0
# 516512    210.0    1824.0 2015-07-23 00:07:00      0.0
# 516537    104.0     813.0 2015-07-23 00:05:00      0.0
# 516547    202.0    1620.0 2015-07-23 00:19:00      0.0
# 516561    232.0    2065.0 2015-07-23 00:16:00      0.0
# 516640    239.0    1947.0 2015-07-23 00:04:00      0.0
# 516708    118.0    1069.0 2015-07-23 00:12:00      0.0
# 516720    138.0    1090.0 2015-07-23 00:07:00      0.0
# 516750    183.0    1546.0 2015-07-23 00:02:00      0.0
# 516769    233.0    2065.0 2015-07-24 00:18:00      0.0
# 516804    216.0    1709.0 2015-07-24 00:31:00      0.0
# 516830    217.0    1620.0 2015-07-24 00:03:00      0.0
# 516888    216.0    1747.0 2015-07-24 00:25:00      0.0
# 516892    142.0    1069.0 2015-07-24 00:04:00      0.0
# 516926    197.0    1678.0 2015-07-24 00:27:00      0.0
# 516939    119.0     977.0 2015-07-24 00:50:00      0.0
# 516958    186.0    1546.0 2015-07-24 00:06:00      0.0
# 517041    202.0    1824.0 2015-07-25 00:45:00      0.0
# 517053    217.0    1620.0 2015-07-25 00:12:00      0.0
# 517055    247.0    2065.0 2015-07-25 00:08:00      0.0
# 517194    194.0    1546.0 2015-07-25 00:07:00      0.0
# 517211    163.0    1436.0 2015-07-25 00:10:00      0.0
# 517230    125.0    1123.0 2015-07-25 00:07:00      0.0
# 517235    186.0    1506.0 2015-07-25 00:08:00      0.0
# 517334      NaN    1436.0 2015-07-26 00:16:00      0.0
# 517365    220.0    1747.0 2015-07-29 00:18:00      0.0
# 517372    127.0     977.0 2015-07-29 00:43:00      0.0
# 517415    152.0    1090.0 2015-07-29 00:08:00      0.0
# 517530    225.0    1620.0 2015-07-30 00:47:00      0.0
#
# [3199 rows x 15 columns]), (1.0,         DayOfWeek Carrier TailNum  FlightNum Origin     OriginCityName  \
# 3881            4      AA  N792AA        185    JFK       New York, NY
# 4934            1      AA  N3DYAA        219    LAX    Los Angeles, CA
# 4938            5      AA  N3KWAA        219    LAX    Los Angeles, CA
# 5647            2      AA  N3DMAA        272    SFO  San Francisco, CA
# 8524            1      AA  N3DTAA        260    LAX    Los Angeles, CA
# 11978           4      AA  N3JBAA       1051    SFO  San Francisco, CA
# 11979           5      AA  N3BCAA       1051    SFO  San Francisco, CA
# 11985           4      AA  N3HNAA       1051    SFO  San Francisco, CA
# 11987           6      AA  N3CRAA       1051    SFO  San Francisco, CA
# 11991           3      AA  N3EWAA       1051    SFO  San Francisco, CA
# 11994           6      AA  N3JVAA       1051    SFO  San Francisco, CA
# 11995           7      AA  N3ABAA       1051    SFO  San Francisco, CA
# 11999           4      AA  N3FKAA       1051    SFO  San Francisco, CA
# 12006           4      AA  N3KMAA       1051    SFO  San Francisco, CA
# 12007           5      AA  N3KTAA       1051    SFO  San Francisco, CA
# 12226           7      AA  N3JCAA       1059    ONT        Ontario, CA
# 12230           7      AA  N3HYAA       1059    ONT        Ontario, CA
# 12898           1      AA  N3DEAA       1113    LAX    Los Angeles, CA
# 12899           2      AA  N3FVAA       1113    LAX    Los Angeles, CA
# 12900           3      AA  N3JGAA       1113    LAX    Los Angeles, CA
# 12902           5      AA  N3JTAA       1113    LAX    Los Angeles, CA
# 12904           1      AA  N3AFAA       1113    LAX    Los Angeles, CA
# 12905           2      AA  N3GUAA       1113    LAX    Los Angeles, CA
# 12906           3      AA  N3CXAA       1113    LAX    Los Angeles, CA
# 12908           5      AA  N3ECAA       1113    LAX    Los Angeles, CA
# 12909           7      AA  N3KYAA       1113    LAX    Los Angeles, CA
# 12910           1      AA  N3BAAA       1113    LAX    Los Angeles, CA
# 12911           2      AA  N3HXAA       1113    LAX    Los Angeles, CA
# 12914           5      AA  N3HSAA       1113    LAX    Los Angeles, CA
# 12917           2      AA  N3EDAA       1113    LAX    Los Angeles, CA
# ...           ...     ...     ...        ...    ...                ...
# 510626          5      F9  N220FR       1270    LAX    Los Angeles, CA
# 510758          5      F9  N932FR        602    DEN         Denver, CO
# 510894          3      F9  N939FR        602    DEN         Denver, CO
# 510941          4      F9  N201FR       1270    LAX    Los Angeles, CA
# 511027          4      F9  N905FR        602    DEN         Denver, CO
# 511230          5      F9  N208FR       1270    LAX    Los Angeles, CA
# 511532          6      F9  N227FR       1270    LAX    Los Angeles, CA
# 511852          1      F9  N213FR       1270    LAX    Los Angeles, CA
# 512118          2      F9  N213FR       1270    LAX    Los Angeles, CA
# 512350          3      F9  N205FR       1270    LAX    Los Angeles, CA
# 512742          7      F9  N933FR        602    DEN         Denver, CO
# 512833          1      F9  N208FR       1270    LAX    Los Angeles, CA
# 513146          2      F9  N228FR       1270    LAX    Los Angeles, CA
# 513369          3      F9  N210FR       1270    LAX    Los Angeles, CA
# 513460          4      F9  N213FR        619    MIA          Miami, FL
# 513461          4      F9  N214FR       1270    LAX    Los Angeles, CA
# 513522          4      F9  N906FR       1262    LAS      Las Vegas, NV
# 513569          4      F9  N922FR       1120    LAS      Las Vegas, NV
# 513685          5      F9  N201FR       1270    LAX    Los Angeles, CA
# 515872          7      F9  N227FR       1270    LAX    Los Angeles, CA
# 516150          1      F9  N902FR        902    ATL        Atlanta, GA
# 516167          1      F9  N908FR       1262    LAS      Las Vegas, NV
# 516290          1      F9  N941FR       1224    LAS      Las Vegas, NV
# 516319          1      F9  N954FR       1120    LAS      Las Vegas, NV
# 516516          4      F9  N207FR       1270    LAX    Los Angeles, CA
# 516647          4      F9  N924FR        602    DEN         Denver, CO
# 516805          5      F9  N214FR       1270    LAX    Los Angeles, CA
# 517054          6      F9  N208FR       1270    LAX    Los Angeles, CA
# 517156          6      F9  N922FR        602    DEN         Denver, CO
# 517313          7      F9  N211FR       1270    LAX    Los Angeles, CA
#
#        OriginStateName Dest           DestCityName DestStateName  DepDelay  \
# 3881          New York  LAX        Los Angeles, CA    California     283.0
# 4934        California  ORD            Chicago, IL      Illinois      78.0
# 4938        California  ORD            Chicago, IL      Illinois      85.0
# 5647        California  MIA              Miami, FL       Florida     108.0
# 8524        California  MIA              Miami, FL       Florida      50.0
# 11978       California  DFW  Dallas/Fort Worth, TX         Texas      21.0
# 11979       California  DFW  Dallas/Fort Worth, TX         Texas      16.0
# 11985       California  DFW  Dallas/Fort Worth, TX         Texas      41.0
# 11987       California  DFW  Dallas/Fort Worth, TX         Texas      14.0
# 11991       California  DFW  Dallas/Fort Worth, TX         Texas      59.0
# 11994       California  DFW  Dallas/Fort Worth, TX         Texas      29.0
# 11995       California  DFW  Dallas/Fort Worth, TX         Texas       1.0
# 11999       California  DFW  Dallas/Fort Worth, TX         Texas      39.0
# 12006       California  DFW  Dallas/Fort Worth, TX         Texas       6.0
# 12007       California  DFW  Dallas/Fort Worth, TX         Texas      45.0
# 12226       California  DFW  Dallas/Fort Worth, TX         Texas      53.0
# 12230       California  DFW  Dallas/Fort Worth, TX         Texas       6.0
# 12898       California  ORD            Chicago, IL      Illinois      11.0
# 12899       California  ORD            Chicago, IL      Illinois      -1.0
# 12900       California  ORD            Chicago, IL      Illinois      -2.0
# 12902       California  ORD            Chicago, IL      Illinois       2.0
# 12904       California  ORD            Chicago, IL      Illinois      -2.0
# 12905       California  ORD            Chicago, IL      Illinois       4.0
# 12906       California  ORD            Chicago, IL      Illinois       9.0
# 12908       California  ORD            Chicago, IL      Illinois      -1.0
# 12909       California  ORD            Chicago, IL      Illinois      10.0
# 12910       California  ORD            Chicago, IL      Illinois      34.0
# 12911       California  ORD            Chicago, IL      Illinois      11.0
# 12914       California  ORD            Chicago, IL      Illinois      -1.0
# 12917       California  ORD            Chicago, IL      Illinois      43.0
# ...                ...  ...                    ...           ...       ...
# 510626      California  ORD            Chicago, IL      Illinois     -14.0
# 510758        Colorado  IND       Indianapolis, IN       Indiana      35.0
# 510894        Colorado  IND       Indianapolis, IN       Indiana      15.0
# 510941      California  ORD            Chicago, IL      Illinois     -16.0
# 511027        Colorado  IND       Indianapolis, IN       Indiana      16.0
# 511230      California  ORD            Chicago, IL      Illinois      -6.0
# 511532      California  ORD            Chicago, IL      Illinois      -2.0
# 511852      California  ORD            Chicago, IL      Illinois      23.0
# 512118      California  ORD            Chicago, IL      Illinois     -12.0
# 512350      California  ORD            Chicago, IL      Illinois     -12.0
# 512742        Colorado  IND       Indianapolis, IN       Indiana      20.0
# 512833      California  ORD            Chicago, IL      Illinois     -22.0
# 513146      California  ORD            Chicago, IL      Illinois      -6.0
# 513369      California  ORD            Chicago, IL      Illinois     -16.0
# 513460         Florida  DEN             Denver, CO      Colorado     227.0
# 513461      California  ORD            Chicago, IL      Illinois      -9.0
# 513522          Nevada  ORD            Chicago, IL      Illinois      99.0
# 513569          Nevada  CVG         Cincinnati, OH      Kentucky     150.0
# 513685      California  ORD            Chicago, IL      Illinois      -5.0
# 515872      California  ORD            Chicago, IL      Illinois     -13.0
# 516150         Georgia  TTN            Trenton, NJ    New Jersey     241.0
# 516167          Nevada  ORD            Chicago, IL      Illinois     117.0
# 516290          Nevada  MCO            Orlando, FL       Florida     114.0
# 516319          Nevada  CVG         Cincinnati, OH      Kentucky     169.0
# 516516      California  ORD            Chicago, IL      Illinois      -9.0
# 516647        Colorado  IND       Indianapolis, IN       Indiana      17.0
# 516805      California  ORD            Chicago, IL      Illinois     -16.0
# 517054      California  ORD            Chicago, IL      Illinois     -17.0
# 517156        Colorado  IND       Indianapolis, IN       Indiana      14.0
# 517313      California  ORD            Chicago, IL      Illinois      -6.0
#
#         AirTime  Distance         DepDateTime  DepHour
# 3881      335.0    2475.0 2015-07-30 01:43:00      1.0
# 4934      193.0    1744.0 2015-07-20 01:13:00      1.0
# 4938      201.0    1744.0 2015-07-24 01:20:00      1.0
# 5647      308.0    2585.0 2015-07-14 01:47:00      1.0
# 8524      280.0    2342.0 2015-07-20 01:00:00      1.0
# 11978     185.0    1464.0 2015-07-02 01:20:00      1.0
# 11979     179.0    1464.0 2015-07-03 01:15:00      1.0
# 11985     168.0    1464.0 2015-07-09 01:40:00      1.0
# 11987     174.0    1464.0 2015-07-11 01:13:00      1.0
# 11991     177.0    1464.0 2015-07-15 01:58:00      1.0
# 11994     175.0    1464.0 2015-07-18 01:28:00      1.0
# 11995     180.0    1464.0 2015-07-19 01:00:00      1.0
# 11999     170.0    1464.0 2015-07-23 01:38:00      1.0
# 12006     185.0    1464.0 2015-07-30 01:05:00      1.0
# 12007     179.0    1464.0 2015-07-31 01:44:00      1.0
# 12226     147.0    1188.0 2015-07-12 01:48:00      1.0
# 12230     147.0    1188.0 2015-07-19 01:01:00      1.0
# 12898     221.0    1744.0 2015-07-06 01:13:00      1.0
# 12899     205.0    1744.0 2015-07-07 01:01:00      1.0
# 12900     205.0    1744.0 2015-07-08 01:00:00      1.0
# 12902     202.0    1744.0 2015-07-10 01:04:00      1.0
# 12904     231.0    1744.0 2015-07-13 01:00:00      1.0
# 12905     203.0    1744.0 2015-07-14 01:06:00      1.0
# 12906     219.0    1744.0 2015-07-15 01:11:00      1.0
# 12908     199.0    1744.0 2015-07-17 01:01:00      1.0
# 12909     197.0    1744.0 2015-07-19 01:12:00      1.0
# 12910     206.0    1744.0 2015-07-20 01:36:00      1.0
# 12911     192.0    1744.0 2015-07-21 01:13:00      1.0
# 12914     199.0    1744.0 2015-07-24 01:01:00      1.0
# 12917     202.0    1744.0 2015-07-28 01:45:00      1.0
# ...         ...       ...                 ...      ...
# 510626    211.0    1744.0 2015-07-10 01:16:00      1.0
# 510758    122.0     977.0 2015-07-10 01:25:00      1.0
# 510894    119.0     977.0 2015-07-15 01:05:00      1.0
# 510941    226.0    1744.0 2015-07-16 01:14:00      1.0
# 511027    127.0     977.0 2015-07-16 01:06:00      1.0
# 511230    215.0    1744.0 2015-07-17 01:24:00      1.0
# 511532    204.0    1744.0 2015-07-18 01:28:00      1.0
# 511852    215.0    1744.0 2015-07-27 01:53:00      1.0
# 512118    203.0    1744.0 2015-07-28 01:18:00      1.0
# 512350    204.0    1744.0 2015-07-29 01:18:00      1.0
# 512742    116.0     977.0 2015-07-19 01:10:00      1.0
# 512833    201.0    1744.0 2015-07-20 01:08:00      1.0
# 513146    203.0    1744.0 2015-07-21 01:24:00      1.0
# 513369    204.0    1744.0 2015-07-22 01:14:00      1.0
# 513460    205.0    1709.0 2015-07-30 01:02:00      1.0
# 513461    208.0    1744.0 2015-07-30 01:21:00      1.0
# 513522    181.0    1514.0 2015-07-30 01:04:00      1.0
# 513569    192.0    1678.0 2015-07-30 01:15:00      1.0
# 513685    206.0    1744.0 2015-07-31 01:25:00      1.0
# 515872    225.0    1744.0 2015-07-05 01:17:00      1.0
# 516150     88.0     701.0 2015-07-06 01:46:00      1.0
# 516167    175.0    1514.0 2015-07-06 01:22:00      1.0
# 516290    274.0    2039.0 2015-07-06 01:09:00      1.0
# 516319    188.0    1678.0 2015-07-06 01:34:00      1.0
# 516516    206.0    1744.0 2015-07-23 01:21:00      1.0
# 516647    115.0     977.0 2015-07-23 01:07:00      1.0
# 516805    207.0    1744.0 2015-07-24 01:14:00      1.0
# 517054    216.0    1744.0 2015-07-25 01:13:00      1.0
# 517156    126.0     977.0 2015-07-25 01:04:00      1.0
# 517313    212.0    1744.0 2015-07-26 01:24:00      1.0
#
# [921 rows x 15 columns]), (2.0,         DayOfWeek Carrier TailNum  FlightNum Origin      OriginCityName  \
# 4338            5      AA  N3FHAA        234    MIA           Miami, FL
# 22478           5      AA  N3DMAA       1391    MIA           Miami, FL
# 26338           1      AA  N3HTAA       1150    PDX        Portland, OR
# 26350           5      AA  N3EWAA       1150    PDX        Portland, OR
# 46816           1      AA  N586UW       2039    CLT       Charlotte, NC
# 51625           5      AA  N151UW       1725    DEN          Denver, CO
# 51901           5      AA  N198UW       1905    PHX         Phoenix, AZ
# 55356           2      AA  N187US       1925    SEA         Seattle, WA
# 56229           1      AA  N153UW       1737    CLT       Charlotte, NC
# 56350           1      AA  N191UW       1812    CLT       Charlotte, NC
# 57486           2      AA  N823AW        479    IAH         Houston, TX
# 61524           7      AA  N584UW       1746    PHX         Phoenix, AZ
# 65857           3      AA  N673AW        520    ANC       Anchorage, AK
# 68978           1      AA  N194UW       1905    PHX         Phoenix, AZ
# 72995           1      AA  N807AW        411    CLT       Charlotte, NC
# 73382           1      AA  N656AW        685    SEA         Seattle, WA
# 75131           3      AS  N525AS        114    ANC       Anchorage, AK
# 75147           3      AS  N796AS        136    ANC       Anchorage, AK
# 75823           4      AS  N587AS        114    ANC       Anchorage, AK
# 75841           4      AS  N592AS        136    ANC       Anchorage, AK
# 76342           5      AS  N568AS        114    ANC       Anchorage, AK
# 76360           5      AS  N713AS        136    ANC       Anchorage, AK
# 76911           5      AS  N525AS        114    ANC       Anchorage, AK
# 76929           5      AS  N317AS        136    ANC       Anchorage, AK
# 76990           3      AA  N173US       1905    PHX         Phoenix, AZ
# 77393           6      AS  N588AS        114    ANC       Anchorage, AK
# 77890           7      AS  N551AS        114    ANC       Anchorage, AK
# 77906           7      AS  N461AS        136    ANC       Anchorage, AK
# 78443           7      AS  N464AS         94    ANC       Anchorage, AK
# 78459           7      AS  N318AS        114    ANC       Anchorage, AK
# ...           ...     ...     ...        ...    ...                 ...
# 393472          1      DL   N3766       1611    FAI       Fairbanks, AK
# 396257          2      DL  N375NC       2324    SLC  Salt Lake City, UT
# 411444          2      DL  N906DA        399    ATL         Atlanta, GA
# 411953          2      DL   N6700       1083    ATL         Atlanta, GA
# 413534          2      DL  N912DN       2416    ATL         Atlanta, GA
# 413674          2      DL  N903DE       2529    ATL         Atlanta, GA
# 414129          3      DL  N352NW       2324    SLC  Salt Lake City, UT
# 414933          2      DL  N931DN       1563    ATL         Atlanta, GA
# 415191          2      DL  N6708D       1768    ATL         Atlanta, GA
# 415192          2      DL  N591NW       1769    ATL         Atlanta, GA
# 419972          5      DL  N378DA       1611    FAI       Fairbanks, AK
# 420462          6      DL  N383DN       1611    FAI       Fairbanks, AK
# 421096          5      AS  N468AS        114    ANC       Anchorage, AK
# 421114          5      AS  N419AS        136    ANC       Anchorage, AK
# 422872          2      B6  N351JB        304    SJU        San Juan, PR
# 429173          1      DL  N919AT        914    LAX     Los Angeles, CA
# 444740          1      DL  N128DL       1406    LAX     Los Angeles, CA
# 460254          5      DL  N349NW       2288    ATL         Atlanta, GA
# 501385          2      DL  N394DA       1611    FAI       Fairbanks, AK
# 508922          5      F9  N201FR       1270    LAX     Los Angeles, CA
# 509100          3      F9  N214FR       1400    SEA         Seattle, WA
# 509866          2      F9  N229FR       1244    SFO   San Francisco, CA
# 509941          2      F9  N926FR        736    DEN          Denver, CO
# 511295          5      F9  N902FR        934    MSP     Minneapolis, MN
# 512594          7      F9  N216FR       1270    LAX     Los Angeles, CA
# 513217          2      F9  N923FR        425    ATL         Atlanta, GA
# 516073          1      F9  N205FR       1270    LAX     Los Angeles, CA
# 516256          1      F9  N931FR       1456    LAS       Las Vegas, NV
# 516538          4      F9  N213FR        223    AUS          Austin, TX
# 516889          5      F9  N919FR       1262    LAS       Las Vegas, NV
#
#        OriginStateName Dest           DestCityName   DestStateName  DepDelay  \
# 4338           Florida  BWI          Baltimore, MD        Maryland     292.0
# 22478          Florida  DFW  Dallas/Fort Worth, TX           Texas     315.0
# 26338           Oregon  DFW  Dallas/Fort Worth, TX           Texas     103.0
# 26350           Oregon  DFW  Dallas/Fort Worth, TX           Texas     129.0
# 46816   North Carolina  MSP        Minneapolis, MN       Minnesota     277.0
# 51625         Colorado  CLT          Charlotte, NC  North Carolina      83.0
# 51901          Arizona  CLT          Charlotte, NC  North Carolina      89.0
# 55356       Washington  CLT          Charlotte, NC  North Carolina     128.0
# 56229   North Carolina  LAX        Los Angeles, CA      California     241.0
# 56350   North Carolina  BOS             Boston, MA   Massachusetts     243.0
# 57486            Texas  PHX            Phoenix, AZ         Arizona     280.0
# 61524          Arizona  DFW  Dallas/Fort Worth, TX           Texas      75.0
# 65857           Alaska  PHX            Phoenix, AZ         Arizona      38.0
# 68978          Arizona  CLT          Charlotte, NC  North Carolina      74.0
# 72995   North Carolina  PWM           Portland, ME           Maine     108.0
# 73382       Washington  PHL       Philadelphia, PA    Pennsylvania     106.0
# 75131           Alaska  SEA            Seattle, WA      Washington      -8.0
# 75147           Alaska  SEA            Seattle, WA      Washington      11.0
# 75823           Alaska  SEA            Seattle, WA      Washington      -6.0
# 75841           Alaska  SEA            Seattle, WA      Washington      -5.0
# 76342           Alaska  SEA            Seattle, WA      Washington       0.0
# 76360           Alaska  SEA            Seattle, WA      Washington      -5.0
# 76911           Alaska  SEA            Seattle, WA      Washington      -6.0
# 76929           Alaska  SEA            Seattle, WA      Washington       8.0
# 76990          Arizona  CLT          Charlotte, NC  North Carolina      74.0
# 77393           Alaska  SEA            Seattle, WA      Washington      -2.0
# 77890           Alaska  SEA            Seattle, WA      Washington     -10.0
# 77906           Alaska  SEA            Seattle, WA      Washington      -4.0
# 78443           Alaska  SEA            Seattle, WA      Washington      84.0
# 78459           Alaska  SEA            Seattle, WA      Washington      -5.0
# ...                ...  ...                    ...             ...       ...
# 393472          Alaska  SEA            Seattle, WA      Washington      29.0
# 396257            Utah  ATL            Atlanta, GA         Georgia      73.0
# 411444         Georgia  MKE          Milwaukee, WI       Wisconsin     231.0
# 411953         Georgia  RDU     Raleigh/Durham, NC  North Carolina     187.0
# 413534         Georgia  TLH        Tallahassee, FL         Florida     176.0
# 413674         Georgia  CLE          Cleveland, OH            Ohio     261.0
# 414129            Utah  ATL            Atlanta, GA         Georgia      70.0
# 414933         Georgia  JAX       Jacksonville, FL         Florida     165.0
# 415191         Georgia  FLL    Fort Lauderdale, FL         Florida     214.0
# 415192         Georgia  MCO            Orlando, FL         Florida     198.0
# 419972          Alaska  SEA            Seattle, WA      Washington      28.0
# 420462          Alaska  SEA            Seattle, WA      Washington      40.0
# 421096          Alaska  SEA            Seattle, WA      Washington      -7.0
# 421114          Alaska  SEA            Seattle, WA      Washington      -1.0
# 422872     Puerto Rico  JFK           New York, NY        New York       0.0
# 429173      California  LAS          Las Vegas, NV          Nevada     337.0
# 444740      California  DTW            Detroit, MI        Michigan     170.0
# 460254         Georgia  BHM         Birmingham, AL         Alabama     178.0
# 501385          Alaska  SEA            Seattle, WA      Washington      34.0
# 508922      California  ORD            Chicago, IL        Illinois      59.0
# 509100      Washington  CLE          Cleveland, OH            Ohio     171.0
# 509866      California  ORD            Chicago, IL        Illinois     216.0
# 509941        Colorado  CVG         Cincinnati, OH        Kentucky     157.0
# 511295       Minnesota  TTN            Trenton, NJ      New Jersey     404.0
# 512594      California  ORD            Chicago, IL        Illinois      36.0
# 513217         Georgia  DEN             Denver, CO        Colorado     355.0
# 516073      California  ORD            Chicago, IL        Illinois      48.0
# 516256          Nevada  ATL            Atlanta, GA         Georgia     227.0
# 516538           Texas  DEN             Denver, CO        Colorado     526.0
# 516889          Nevada  ORD            Chicago, IL        Illinois     166.0
#
#         AirTime  Distance         DepDateTime  DepHour
# 4338      121.0     946.0 2015-07-31 02:12:00      2.0
# 22478     142.0    1121.0 2015-07-31 02:40:00      2.0
# 26338     195.0    1616.0 2015-07-06 02:33:00      2.0
# 26350     194.0    1616.0 2015-07-24 02:59:00      2.0
# 46816     125.0     930.0 2015-07-06 02:57:00      2.0
# 51625     156.0    1337.0 2015-07-10 02:43:00      2.0
# 51901     208.0    1773.0 2015-07-10 02:39:00      2.0
# 55356     278.0    2279.0 2015-07-14 02:33:00      2.0
# 56229     260.0    2125.0 2015-07-13 02:11:00      2.0
# 56350      99.0     728.0 2015-07-13 02:15:00      2.0
# 57486     121.0    1009.0 2015-07-14 02:05:00      2.0
# 61524     110.0     868.0 2015-07-19 02:05:00      2.0
# 65857     287.0    2552.0 2015-07-22 02:03:00      2.0
# 68978     216.0    1773.0 2015-07-20 02:24:00      2.0
# 72995     106.0     813.0 2015-07-27 02:08:00      2.0
# 73382     273.0    2378.0 2015-07-27 02:21:00      2.0
# 75131     186.0    1448.0 2015-07-01 02:32:00      2.0
# 75147     182.0    1448.0 2015-07-01 02:06:00      2.0
# 75823     182.0    1448.0 2015-07-02 02:34:00      2.0
# 75841     182.0    1448.0 2015-07-02 02:00:00      2.0
# 76342     173.0    1448.0 2015-07-03 02:40:00      2.0
# 76360     175.0    1448.0 2015-07-03 02:00:00      2.0
# 76911     196.0    1448.0 2015-07-10 02:34:00      2.0
# 76929     187.0    1448.0 2015-07-10 02:13:00      2.0
# 76990     209.0    1773.0 2015-07-29 02:24:00      2.0
# 77393     168.0    1448.0 2015-07-04 02:38:00      2.0
# 77890     171.0    1448.0 2015-07-05 02:30:00      2.0
# 77906     171.0    1448.0 2015-07-05 02:01:00      2.0
# 78443     183.0    1448.0 2015-07-12 02:49:00      2.0
# 78459     180.0    1448.0 2015-07-12 02:35:00      2.0
# ...         ...       ...                 ...      ...
# 393472    170.0    1533.0 2015-07-06 02:04:00      2.0
# 396257    191.0    1590.0 2015-07-07 02:12:00      2.0
# 411444     95.0     669.0 2015-07-14 02:11:00      2.0
# 411953     52.0     356.0 2015-07-14 02:12:00      2.0
# 413534     38.0     223.0 2015-07-14 02:01:00      2.0
# 413674     76.0     554.0 2015-07-14 02:25:00      2.0
# 414129    201.0    1590.0 2015-07-15 02:09:00      2.0
# 414933     39.0     270.0 2015-07-14 02:10:00      2.0
# 415191     77.0     581.0 2015-07-14 02:43:00      2.0
# 415192     55.0     404.0 2015-07-14 02:30:00      2.0
# 419972    171.0    1533.0 2015-07-17 02:03:00      2.0
# 420462    180.0    1533.0 2015-07-18 02:15:00      2.0
# 421096    178.0    1448.0 2015-07-31 02:33:00      2.0
# 421114    178.0    1448.0 2015-07-31 02:04:00      2.0
# 422872    208.0    1598.0 2015-07-21 02:06:00      2.0
# 429173     41.0     236.0 2015-07-20 02:47:00      2.0
# 444740    232.0    1979.0 2015-07-27 02:00:00      2.0
# 460254     27.0     134.0 2015-07-31 02:17:00      2.0
# 501385    181.0    1533.0 2015-07-28 02:09:00      2.0
# 508922    209.0    1744.0 2015-07-03 02:29:00      2.0
# 509100    227.0    2021.0 2015-07-15 02:21:00      2.0
# 509866    249.0    1846.0 2015-07-07 02:01:00      2.0
# 509941    129.0    1069.0 2015-07-07 02:42:00      2.0
# 511295    137.0     989.0 2015-07-17 02:39:00      2.0
# 512594    196.0    1744.0 2015-07-19 02:06:00      2.0
# 513217    160.0    1199.0 2015-07-21 02:15:00      2.0
# 516073    219.0    1744.0 2015-07-06 02:18:00      2.0
# 516256    217.0    1747.0 2015-07-06 02:02:00      2.0
# 516538     96.0     775.0 2015-07-23 02:06:00      2.0
# 516889    180.0    1514.0 2015-07-24 02:11:00      2.0
#
# [275 rows x 15 columns]), (3.0,         DayOfWeek Carrier TailNum  FlightNum Origin      OriginCityName  \
# 31919           3      AA  N5ESAA       2255    LAX     Los Angeles, CA
# 41376           5      AA  N3AUAA       2461    MIA           Miami, FL
# 52944           6      AA  N656AW        520    ANC       Anchorage, AK
# 63680           4      AA  N519UW        703    PHX         Phoenix, AZ
# 71614           3      AA  N656AW        685    SEA         Seattle, WA
# 74671           5      AA  N545UW       1905    PHX         Phoenix, AZ
# 90015           3      B6  N509JB        730    BQN       Aguadilla, PR
# 90030           3      B6  N658JB        768    PSE           Ponce, PR
# 91122           5      B6  N763JB        730    BQN       Aguadilla, PR
# 91137           5      B6  N563JB        768    PSE           Ponce, PR
# 91491           5      B6  N605JB       2152    SJU        San Juan, PR
# 91501           5      B6  N521JB       2276    SJU        San Juan, PR
# 92612           4      B6  N566JB        730    BQN       Aguadilla, PR
# 92627           4      B6  N534JB        768    PSE           Ponce, PR
# 93303           7      B6  N641JB       2276    SJU        San Juan, PR
# 93978           6      B6  N605JB       2276    SJU        San Juan, PR
# 94377           7      B6  N729JB        730    BQN       Aguadilla, PR
# 94392           7      B6  N593JB        768    PSE           Ponce, PR
# 94714           3      B6  N563JB        730    BQN       Aguadilla, PR
# 94729           3      B6  N651JB        768    PSE           Ponce, PR
# 94739           3      B6  N607JB        802    SLC  Salt Lake City, UT
# 96805           6      B6  N633JB        730    BQN       Aguadilla, PR
# 96819           6      B6  N249JB        768    PSE           Ponce, PR
# 97128           2      B6  N554JB        730    BQN       Aguadilla, PR
# 97143           2      B6  N643JB        768    PSE           Ponce, PR
# 97497           2      B6  N627JB       2276    SJU        San Juan, PR
# 98228           4      B6  N510JB       2152    SJU        San Juan, PR
# 98643           5      B6  N645JB        730    BQN       Aguadilla, PR
# 98658           5      B6  N564JB        768    PSE           Ponce, PR
# 99021           5      B6  N510JB       2276    SJU        San Juan, PR
# ...           ...     ...     ...        ...    ...                 ...
# 291740          6      NK  N608NK        374    BQN       Aguadilla, PR
# 291743          4      NK  N608NK        374    BQN       Aguadilla, PR
# 291746          2      NK  N517NK        374    BQN       Aguadilla, PR
# 291751          4      NK  N607NK        374    BQN       Aguadilla, PR
# 291754          2      NK  N512NK        374    BQN       Aguadilla, PR
# 292272          1      NK  N620NK        647    IAG   Niagara Falls, NY
# 293419          2      NK  N605NK        451    PBG     Plattsburgh, NY
# 293425          2      NK  N602NK        451    PBG     Plattsburgh, NY
# 355195          1      UA  N73299       1162    BQN       Aguadilla, PR
# 359297          6      UA  N38257       1254    SJU        San Juan, PR
# 359601          6      UA  N54241       1740    SJU        San Juan, PR
# 365002          3      UA  N14228       1162    BQN       Aguadilla, PR
# 368646          7      UA  N76265       1162    BQN       Aguadilla, PR
# 369299          2      UA  N57870       1291    ANC       Anchorage, AK
# 369991          7      UA  N37281         15    SJU        San Juan, PR
# 370443          6      UA  N73275         15    SJU        San Juan, PR
# 374424          4      UA  N76517       1740    SJU        San Juan, PR
# 375203          3      UA  N14230       1740    SJU        San Juan, PR
# 376932          4      UA  N37474       1162    BQN       Aguadilla, PR
# 381707          3      UA  N33209       1162    BQN       Aguadilla, PR
# 384001          5      UA  N37274       1740    SJU        San Juan, PR
# 384874          5      UA  N35260       1162    BQN       Aguadilla, PR
# 387178          2      UA  N73259       1162    BQN       Aguadilla, PR
# 388506          1      UA  N18243       1162    BQN       Aguadilla, PR
# 389339          7      UA  N78285         15    SJU        San Juan, PR
# 397686          4      DL  N360NW       2324    SLC  Salt Lake City, UT
# 417493          4      DL  N328NW       2324    SLC  Salt Lake City, UT
# 422680          1      B6  N633JB       2276    SJU        San Juan, PR
# 449712          3      DL  N3755D       1611    FAI       Fairbanks, AK
# 509833          2      F9  N218FR       1270    LAX     Los Angeles, CA
#
#        OriginStateName Dest           DestCityName   DestStateName  DepDelay  \
# 31919       California  DFW  Dallas/Fort Worth, TX           Texas     165.0
# 41376          Florida  MCO            Orlando, FL         Florida     196.0
# 52944           Alaska  PHX            Phoenix, AZ         Arizona     105.0
# 63680          Arizona  PDX           Portland, OR          Oregon     269.0
# 71614       Washington  PHL       Philadelphia, PA    Pennsylvania     157.0
# 74671          Arizona  CLT          Charlotte, NC  North Carolina     115.0
# 90015      Puerto Rico  MCO            Orlando, FL         Florida     -10.0
# 90030      Puerto Rico  MCO            Orlando, FL         Florida       8.0
# 91122      Puerto Rico  MCO            Orlando, FL         Florida      27.0
# 91137      Puerto Rico  MCO            Orlando, FL         Florida      14.0
# 91491      Puerto Rico  TPA              Tampa, FL         Florida      -3.0
# 91501      Puerto Rico  BDL           Hartford, CT     Connecticut       2.0
# 92612      Puerto Rico  MCO            Orlando, FL         Florida       0.0
# 92627      Puerto Rico  MCO            Orlando, FL         Florida     -12.0
# 93303      Puerto Rico  BDL           Hartford, CT     Connecticut     -11.0
# 93978      Puerto Rico  BDL           Hartford, CT     Connecticut      -1.0
# 94377      Puerto Rico  MCO            Orlando, FL         Florida     -10.0
# 94392      Puerto Rico  MCO            Orlando, FL         Florida     -12.0
# 94714      Puerto Rico  MCO            Orlando, FL         Florida      -2.0
# 94729      Puerto Rico  MCO            Orlando, FL         Florida     -15.0
# 94739             Utah  MCO            Orlando, FL         Florida     197.0
# 96805      Puerto Rico  MCO            Orlando, FL         Florida     -10.0
# 96819      Puerto Rico  MCO            Orlando, FL         Florida     -10.0
# 97128      Puerto Rico  MCO            Orlando, FL         Florida     -10.0
# 97143      Puerto Rico  MCO            Orlando, FL         Florida     -11.0
# 97497      Puerto Rico  BDL           Hartford, CT     Connecticut      -6.0
# 98228      Puerto Rico  TPA              Tampa, FL         Florida      -5.0
# 98643      Puerto Rico  MCO            Orlando, FL         Florida     -11.0
# 98658      Puerto Rico  MCO            Orlando, FL         Florida     -12.0
# 99021      Puerto Rico  BDL           Hartford, CT     Connecticut      -2.0
# ...                ...  ...                    ...             ...       ...
# 291740     Puerto Rico  FLL    Fort Lauderdale, FL         Florida      11.0
# 291743     Puerto Rico  FLL    Fort Lauderdale, FL         Florida       0.0
# 291746     Puerto Rico  FLL    Fort Lauderdale, FL         Florida       0.0
# 291751     Puerto Rico  FLL    Fort Lauderdale, FL         Florida      35.0
# 291754     Puerto Rico  FLL    Fort Lauderdale, FL         Florida      -4.0
# 292272        New York  FLL    Fort Lauderdale, FL         Florida      37.0
# 293419        New York  FLL    Fort Lauderdale, FL         Florida      54.0
# 293425        New York  FLL    Fort Lauderdale, FL         Florida      20.0
# 355195     Puerto Rico  EWR             Newark, NJ      New Jersey     103.0
# 359297     Puerto Rico  IAD         Washington, DC        Virginia      28.0
# 359601     Puerto Rico  EWR             Newark, NJ      New Jersey     105.0
# 365002     Puerto Rico  EWR             Newark, NJ      New Jersey     113.0
# 368646     Puerto Rico  EWR             Newark, NJ      New Jersey     127.0
# 369299          Alaska  IAH            Houston, TX           Texas     428.0
# 369991     Puerto Rico  EWR             Newark, NJ      New Jersey      -2.0
# 370443     Puerto Rico  EWR             Newark, NJ      New Jersey      -3.0
# 374424     Puerto Rico  EWR             Newark, NJ      New Jersey      86.0
# 375203     Puerto Rico  EWR             Newark, NJ      New Jersey      65.0
# ...
# 4925      197.0    1744.0 2015-07-11 23:56:00     23.0
# 4926      201.0    1744.0 2015-07-12 23:53:00     23.0
# 4927      208.0    1744.0 2015-07-13 23:55:00     23.0
# 4928      213.0    1744.0 2015-07-14 23:52:00     23.0
# 4929      234.0    1744.0 2015-07-15 23:47:00     23.0
# 4930      199.0    1744.0 2015-07-16 23:56:00     23.0
# 4932      196.0    1744.0 2015-07-18 23:55:00     23.0
# 4933      199.0    1744.0 2015-07-19 23:55:00     23.0
# 4935      201.0    1744.0 2015-07-21 23:54:00     23.0
# 4936      203.0    1744.0 2015-07-22 23:50:00     23.0
# 4939      196.0    1744.0 2015-07-25 23:52:00     23.0
# 4941      201.0    1744.0 2015-07-27 23:52:00     23.0
# 4942      200.0    1744.0 2015-07-28 23:51:00     23.0
# 4944      204.0    1744.0 2015-07-30 23:57:00     23.0
# 4945      213.0    1744.0 2015-07-31 23:56:00     23.0
# 5127      427.0    3784.0 2015-07-18 23:09:00     23.0
# 5634      321.0    2585.0 2015-07-01 23:58:00     23.0
# 5635      309.0    2585.0 2015-07-02 23:56:00     23.0
# ...         ...       ...                 ...      ...
# 516757    173.0    1506.0 2015-07-23 23:56:00     23.0
# 516787    213.0    1709.0 2015-07-24 23:24:00     23.0
# 516835    223.0    2021.0 2015-07-24 23:25:00     23.0
# 516857    133.0    1123.0 2015-07-24 23:56:00     23.0
# 516867    172.0    1436.0 2015-07-24 23:56:00     23.0
# 516878    143.0    1090.0 2015-07-24 23:45:00     23.0
# 516975    185.0    1506.0 2015-07-24 23:58:00     23.0
# 516992     87.0     666.0 2015-07-24 23:19:00     23.0
# 516995    250.0    2039.0 2015-07-24 23:34:00     23.0
# 517089    202.0    1709.0 2015-07-25 23:05:00     23.0
# 517108    225.0    2021.0 2015-07-25 23:25:00     23.0
# 517115    131.0    1069.0 2015-07-25 23:57:00     23.0
# 517145    200.0    1678.0 2015-07-25 23:44:00     23.0
# 517169    247.0    1947.0 2015-07-25 23:04:00     23.0
# 517175    170.0    1514.0 2015-07-25 23:25:00     23.0
# 517242    139.0    1090.0 2015-07-25 23:55:00     23.0
# 517259    261.0    2039.0 2015-07-25 23:29:00     23.0
# 517285    227.0    2021.0 2015-07-26 23:27:00     23.0
# 517328    214.0    1824.0 2015-07-26 23:19:00     23.0
# 517333    235.0    1620.0 2015-07-26 23:08:00     23.0
# 517371    177.0    1514.0 2015-07-29 23:19:00     23.0
# 517434    167.0    1436.0 2015-07-29 23:47:00     23.0
# 517452    192.0    1678.0 2015-07-29 23:10:00     23.0
# 517461    178.0    1506.0 2015-07-29 23:54:00     23.0
# 517462    136.0    1069.0 2015-07-29 23:55:00     23.0
# 517476    120.0    1123.0 2015-07-29 23:42:00     23.0
# 517494    183.0    1546.0 2015-07-29 23:55:00     23.0
# 517497    249.0    2039.0 2015-07-29 23:27:00     23.0
# 519092    323.0    2640.0 2015-07-22 23:32:00     23.0
# 520602     20.0     102.0 2015-07-12 23:00:00     23.0
#
# [6770 rows x 15 columns])]
# (0.0,         DayOfWeek Carrier TailNum  FlightNum Origin     OriginCityName  \
# 2290            1      AA  N3EEAA         91    ORD        Chicago, IL
# 4323            4      AA  N3EXAA        234    MIA          Miami, FL
# 4922            3      AA  N3HRAA        219    LAX    Los Angeles, CA
# 4923            4      AA  N3HUAA        219    LAX    Los Angeles, CA
# 4924            5      AA  N3GWAA        219    LAX    Los Angeles, CA
# 4931            5      AA  N3AJAA        219    LAX    Los Angeles, CA
# 4937            4      AA  N3LEAA        219    LAX    Los Angeles, CA
# 4940            7      AA  N3CDAA        219    LAX    Los Angeles, CA
# 4943            3      AA  N3HAAA        219    LAX    Los Angeles, CA
# 5639            1      AA  N3EPAA        272    SFO  San Francisco, CA
# 5645            7      AA  N3BJAA        272    SFO  San Francisco, CA
# 5650            5      AA  N3EFAA        272    SFO  San Francisco, CA
# 5651            6      AA  N3FAAA        272    SFO  San Francisco, CA
# 5652            7      AA  N3FRAA        272    SFO  San Francisco, CA
# 5655            3      AA  N3JEAA        272    SFO  San Francisco, CA
# 5656            4      AA  N3GWAA        272    SFO  San Francisco, CA
# 5659            7      AA  N3LKAA        272    SFO  San Francisco, CA
# 5664            5      AA  N3JGAA        272    SFO  San Francisco, CA
# 5968            1      AA  N5ESAA        285    LAX    Los Angeles, CA
# 5980            3      AA  N5DGAA        286    LIH          Lihue, HI
# 8505            3      AA  N3BHAA        260    LAX    Los Angeles, CA
# 8506            4      AA  N3AKAA        260    LAX    Los Angeles, CA
# 8507            5      AA  N3FHAA        260    LAX    Los Angeles, CA
# 8508            6      AA  N3DHAA        260    LAX    Los Angeles, CA
# 8509            7      AA  N3JMAA        260    LAX    Los Angeles, CA
# 8510            1      AA  N3BHAA        260    LAX    Los Angeles, CA
# 8511            2      AA  N3HGAA        260    LAX    Los Angeles, CA
# 8512            3      AA  N3DUAA        260    LAX    Los Angeles, CA
# 8513            4      AA  N3BAAA        260    LAX    Los Angeles, CA
# 8514            5      AA  N3FFAA        260    LAX    Los Angeles, CA
# ...           ...     ...     ...        ...    ...                ...
# 516343          2      F9  N208FR       1126    LAS      Las Vegas, NV
# 516482          3      F9  N953FR        736    DEN         Denver, CO
# 516512          4      F9  N205FR       1114    LAS      Las Vegas, NV
# 516537          4      F9  N213FR        223    ATL        Atlanta, GA
# 516547          4      F9  N216FR        507    LGA       New York, NY
# 516561          4      F9  N227FR       1126    LAS      Las Vegas, NV
# 516640          4      F9  N922FR       1478    LAX    Los Angeles, CA
# 516708          4      F9  N939FR        736    DEN         Denver, CO
# 516720          4      F9  N943FR       1136    LAS      Las Vegas, NV
# 516750          4      F9  N953FR        682    DEN         Denver, CO
# 516769          5      F9  N203FR       1126    LAS      Las Vegas, NV
# 516804          5      F9  N213FR        619    MIA          Miami, FL
# 516830          5      F9  N223FR        507    LGA       New York, NY
# 516888          5      F9  N919FR       1457    ATL        Atlanta, GA
# 516892          5      F9  N921FR        736    DEN         Denver, CO
# 516926          5      F9  N926FR       1120    LAS      Las Vegas, NV
# 516939          5      F9  N929FR        602    DEN         Denver, CO
# 516958          5      F9  N933FR        682    DEN         Denver, CO
# 517041          6      F9  N205FR       1114    LAS      Las Vegas, NV
# 517053          6      F9  N207FR        507    LGA       New York, NY
# 517055          6      F9  N209FR       1126    LAS      Las Vegas, NV
# 517194          6      F9  N928FR        682    DEN         Denver, CO
# 517211          6      F9  N933FR        565    DEN         Denver, CO
# 517230          6      F9  N939FR        620    DEN         Denver, CO
# 517235          6      F9  N943FR        300    DEN         Denver, CO
# 517334          7      F9  N216FR        565    DEN         Denver, CO
# 517365          3      F9  N912FR       1456    LAS      Las Vegas, NV
# 517372          3      F9  N919FR        602    DEN         Denver, CO
# 517415          3      F9  N926FR       1136    LAS      Las Vegas, NV
# 517530          4      F9  N208FR        507    LGA       New York, NY
#
#        OriginStateName Dest           DestCityName   DestStateName  DepDelay  \
# 2290          Illinois  DFW  Dallas/Fort Worth, TX           Texas     105.0
# 4323           Florida  BWI          Baltimore, MD        Maryland     196.0
# 4922        California  ORD            Chicago, IL        Illinois      15.0
# 4923        California  ORD            Chicago, IL        Illinois      17.0
# 4924        California  ORD            Chicago, IL        Illinois      36.0
# 4931        California  ORD            Chicago, IL        Illinois       5.0
# 4937        California  ORD            Chicago, IL        Illinois       7.0
# 4940        California  ORD            Chicago, IL        Illinois      34.0
# 4943        California  ORD            Chicago, IL        Illinois      10.0
# 5639        California  MIA              Miami, FL         Florida      25.0
# 5645        California  MIA              Miami, FL         Florida      12.0
# 5650        California  MIA              Miami, FL         Florida      10.0
# 5651        California  MIA              Miami, FL         Florida      16.0
# 5652        California  MIA              Miami, FL         Florida      14.0
# 5655        California  MIA              Miami, FL         Florida      27.0
# 5656        California  MIA              Miami, FL         Florida      15.0
# 5659        California  MIA              Miami, FL         Florida       3.0
# 5664        California  MIA              Miami, FL         Florida      14.0
# 5968        California  LIH              Lihue, HI          Hawaii     410.0
# 5980            Hawaii  LAX        Los Angeles, CA      California     161.0
# 8505        California  MIA              Miami, FL         Florida      -5.0
# 8506        California  MIA              Miami, FL         Florida      -5.0
# 8507        California  MIA              Miami, FL         Florida      -6.0
# 8508        California  MIA              Miami, FL         Florida      -3.0
# 8509        California  MIA              Miami, FL         Florida      -3.0
# 8510        California  MIA              Miami, FL         Florida      -4.0
# 8511        California  MIA              Miami, FL         Florida      -5.0
# 8512        California  MIA              Miami, FL         Florida      -2.0
# 8513        California  MIA              Miami, FL         Florida      -4.0
# 8514        California  MIA              Miami, FL         Florida     -10.0
# ...                ...  ...                    ...             ...       ...
# 516343          Nevada  IAD         Washington, DC        Virginia      -1.0
# 516482        Colorado  CVG         Cincinnati, OH        Kentucky      38.0
# 516512          Nevada  CLE          Cleveland, OH            Ohio      47.0
# 516537         Georgia  AUS             Austin, TX           Texas     525.0
# 516547        New York  DEN             Denver, CO        Colorado      89.0
# 516561          Nevada  IAD         Washington, DC        Virginia       1.0
# 516640      California  ATL            Atlanta, GA         Georgia      64.0
# 516708        Colorado  CVG         Cincinnati, OH        Kentucky       7.0
# 516720          Nevada  AUS             Austin, TX           Texas      12.0
# 516750        Colorado  MCO            Orlando, FL         Florida       3.0
# 516769          Nevada  IAD         Washington, DC        Virginia       3.0
# 516804         Florida  DEN             Denver, CO        Colorado     196.0
# 516830        New York  DEN             Denver, CO        Colorado      73.0
# 516888         Georgia  LAS          Las Vegas, NV          Nevada     225.0
# 516892        Colorado  CVG         Cincinnati, OH        Kentucky      -1.0
# 516926          Nevada  CVG         Cincinnati, OH        Kentucky     102.0
# 516939        Colorado  IND       Indianapolis, IN         Indiana       0.0
# 516958        Colorado  MCO            Orlando, FL         Florida       7.0
# 517041          Nevada  CLE          Cleveland, OH            Ohio      85.0
# 517053        New York  DEN             Denver, CO        Colorado      82.0
# 517055          Nevada  IAD         Washington, DC        Virginia      -7.0
# 517194        Colorado  MCO            Orlando, FL         Florida       8.0
# 517211        Colorado  RDU     Raleigh/Durham, NC  North Carolina      15.0
# 517230        Colorado  DTW            Detroit, MI        Michigan      21.0
# 517235        Colorado  TPA              Tampa, FL         Florida       9.0
# 517334        Colorado  RDU     Raleigh/Durham, NC  North Carolina      21.0
# 517365          Nevada  ATL            Atlanta, GA         Georgia     123.0
# 517372        Colorado  IND       Indianapolis, IN         Indiana      -7.0
# 517415          Nevada  AUS             Austin, TX           Texas      13.0
# 517530        New York  DEN             Denver, CO        Colorado     117.0
#
#         AirTime  Distance         DepDateTime  DepHour
# 2290      110.0     802.0 2015-07-06 00:00:00      0.0
# 4323      129.0     946.0 2015-07-16 00:36:00      0.0
# 4922      213.0    1744.0 2015-07-08 00:10:00      0.0
# 4923      206.0    1744.0 2015-07-09 00:12:00      0.0
# 4924      202.0    1744.0 2015-07-10 00:31:00      0.0
# 4931      197.0    1744.0 2015-07-17 00:00:00      0.0
# 4937      217.0    1744.0 2015-07-23 00:02:00      0.0
# 4940      209.0    1744.0 2015-07-26 00:29:00      0.0
# 4943      207.0    1744.0 2015-07-29 00:05:00      0.0
# 5639      315.0    2585.0 2015-07-06 00:24:00      0.0
# 5645      309.0    2585.0 2015-07-12 00:11:00      0.0
# 5650      305.0    2585.0 2015-07-17 00:09:00      0.0
# 5651      303.0    2585.0 2015-07-18 00:15:00      0.0
# 5652      308.0    2585.0 2015-07-19 00:13:00      0.0
# 5655      300.0    2585.0 2015-07-22 00:26:00      0.0
# 5656      299.0    2585.0 2015-07-23 00:14:00      0.0
# 5659      313.0    2585.0 2015-07-26 00:02:00      0.0
# 5664      302.0    2585.0 2015-07-31 00:13:00      0.0
# 5968      330.0    2615.0 2015-07-27 00:20:00      0.0
# 5980      296.0    2615.0 2015-07-08 00:42:00      0.0
# 8505      292.0    2342.0 2015-07-01 00:05:00      0.0
# 8506      288.0    2342.0 2015-07-02 00:05:00      0.0
# 8507      285.0    2342.0 2015-07-03 00:04:00      0.0
# 8508      285.0    2342.0 2015-07-04 00:07:00      0.0
# 8509      277.0    2342.0 2015-07-05 00:07:00      0.0
# 8510      284.0    2342.0 2015-07-06 00:06:00      0.0
# 8511      287.0    2342.0 2015-07-07 00:05:00      0.0
# 8512      276.0    2342.0 2015-07-08 00:08:00      0.0
# 8513      273.0    2342.0 2015-07-09 00:06:00      0.0
# 8514      295.0    2342.0 2015-07-10 00:00:00      0.0
# ...         ...       ...                 ...      ...
# 516343    249.0    2065.0 2015-07-07 00:14:00      0.0
# 516482    122.0    1069.0 2015-07-22 00:43:00      0.0
# 516512    210.0    1824.0 2015-07-23 00:07:00      0.0
# 516537    104.0     813.0 2015-07-23 00:05:00      0.0
# 516547    202.0    1620.0 2015-07-23 00:19:00      0.0
# 516561    232.0    2065.0 2015-07-23 00:16:00      0.0
# 516640    239.0    1947.0 2015-07-23 00:04:00      0.0
# 516708    118.0    1069.0 2015-07-23 00:12:00      0.0
# 516720    138.0    1090.0 2015-07-23 00:07:00      0.0
# 516750    183.0    1546.0 2015-07-23 00:02:00      0.0
# 516769    233.0    2065.0 2015-07-24 00:18:00      0.0
# 516804    216.0    1709.0 2015-07-24 00:31:00      0.0
# 516830    217.0    1620.0 2015-07-24 00:03:00      0.0
# 516888    216.0    1747.0 2015-07-24 00:25:00      0.0
# 516892    142.0    1069.0 2015-07-24 00:04:00      0.0
# 516926    197.0    1678.0 2015-07-24 00:27:00      0.0
# 516939    119.0     977.0 2015-07-24 00:50:00      0.0
# 516958    186.0    1546.0 2015-07-24 00:06:00      0.0
# 517041    202.0    1824.0 2015-07-25 00:45:00      0.0
# 517053    217.0    1620.0 2015-07-25 00:12:00      0.0
# 517055    247.0    2065.0 2015-07-25 00:08:00      0.0
# 517194    194.0    1546.0 2015-07-25 00:07:00      0.0
# 517211    163.0    1436.0 2015-07-25 00:10:00      0.0
# 517230    125.0    1123.0 2015-07-25 00:07:00      0.0
# 517235    186.0    1506.0 2015-07-25 00:08:00      0.0
# 517334      NaN    1436.0 2015-07-26 00:16:00      0.0
# 517365    220.0    1747.0 2015-07-29 00:18:00      0.0
# 517372    127.0     977.0 2015-07-29 00:43:00      0.0
# 517415    152.0    1090.0 2015-07-29 00:08:00      0.0
# 517530    225.0    1620.0 2015-07-30 00:47:00      0.0
#
# [3199 rows x 15 columns]) (3199, 15)

# %% [markdown]
# ### Everything looks ok! let's plot this thing!

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

ax1.set_ylim(-20, 240)

bp = plt.boxplot(groups)

labels = plt.setp(ax1, xticklabels=hours)
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
